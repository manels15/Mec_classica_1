# %% [markdown]
# ## Lista 1- Problemas numéricos - Unidade 1
#
# FIS 0615 - Mecânica Clássica 1
#
# Professor: Doutor Edimilson Félix da Silva
#
# Alunos: Allan Martin Correia de Medeiros, José Emanuel Vasconcelos Oliveira, Marcelo Benevides de Souza, Yago Brasil de Lima, Yves Ferreira Vicente
#
# Data: 05/05/2025

# %% [markdown]
# # Sumário
#
# - [Problema 1](#Problema-1)
# - [Problema 2](#Problema-2)
# - [Problema 3](#Problema-3)
# - [Problema 4](#Problema-4)
# - [Problema 5](#Problema-5)
# - [Problema 6](#Problema-6)
# - [Problema 7](#Problema-7)
# - [Problema 8](#Problema-8)
# - [Problema 9](#Problema-9)
# - [Problema 10](#Problema-10)
# - [Problema 11](#Problema-11)
# - [Problema 12](#Problema-12)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as const

# %% [markdown]
# ## Problema 1

# %% [markdown]
# **Movimento horizontal de uma partícula sujeita a uma força variável no tempo.** Uma partícula de massa $𝑚 = 1 kg$ está sujeita a uma força unidimensional $F(t) = kt e^{-\alpha t}$, onde $𝑘 = 1 \ N/s$ e $𝛼 = 0,5 \ s^{-1}$. Se a partícula estiver inicialmente em repouso, calcule e elabore um gráfico da posição, velocidade e aceleração da partícula como função do tempo.
#
# **Objetivo**: Primeiro, vamos utilizar dos conceitos de velocidade e aceleração para buscarmos fórmulas que descrevam a velocidade e a posição em função do tempo para essa força variável. Posteriormente, vamos fazer gráficos que retratem tais grandezas.

# %% [markdown]
# **Desenvolvimento Teórico:** A segunda Lei de Newton, em termos matemáticos, nos diz que:

# %% [markdown]
# $$
# \vec{F} = \frac{d \vec{p}}{dt},
# \tag{1.1}
# $$

# %% [markdown]
# onde $\vec{p} = m\vec{v}$, representa o momento linear. Como a partícula não tem variação de massa, logo a mesma é constante com relação ao tempo. Dessa forma, podemos escrever (1.1) como:

# %% [markdown]
# $$
# \vec{F} = m \frac{d\vec{v}}{dt}.
# $$

# %% [markdown]
# Agora, utilizemos a definição de aceleração:

# %% [markdown]
# $$
# \vec{a} = \frac{d\vec{v}}{dt}.
# $$

# %% [markdown]
# Substituindo na equação da força, obtemos então, finalmente:

# %% [markdown]
# $$
# \vec{F} = m\vec{a} \Rightarrow \vec{a} = \frac{\vec{F}}{m}.
# \tag{1.2}
# $$

# %% [markdown]
# A equação (1.2) descreve a aceleração de um corpo em termos da força resultante aplicada sobre ele, dividido por sua massa. Para o nosso problema, temos que a força atuante é unidimensional. Dessa forma, não precisamos nos preocupar com análises vetoriais. Vamos considerar que a partícula se mova apenas na direção do eixo $x$. Assim, a aceleração sentida pelo corpo é:

# %% [markdown]
# $$
# a(t) = \frac{kte^{-\alpha t}}{1 \ kg} \rightarrow a(t) = Cte^{-\alpha t},
# \tag{1.3}
# $$

# %% [markdown]
# onde modificamos a constante $k$ por $C$, para indicar a mudança das unidades de medida. Entretanto, ambas apresentam o mesmo módulo.

# %% [markdown]
# Utilizando o conceito de aceleração descrito anteriormente, facilmente obtemos um método de encontrar a velocidade, tendo em mão a aceleração:

# %% [markdown]
# $$
# \int dv = \int a dt \Rightarrow v = \int a dt.
# $$

# %% [markdown]
# Note que dispensamos o uso de vetores, por se tratar de um movimento unidimensional. Substituindo pela expressão da aceleração encontrada em (1.3), teremos:

# %% [markdown]
# $$
# \begin{aligned}
# v(t) = \int C t e^{- \alpha t} \ dt \Rightarrow v(t) = C \left( \frac{te^{-\alpha t}}{-\alpha} + \frac{1}{\alpha}\int e^{-\alpha t} \ dt\right) \\ \\
# \Rightarrow v(t) = C \left(\frac{te^{-\alpha t}}{-\alpha} + \frac{1}{\alpha} \left(\frac{e^{-\alpha t}}{-\alpha}\right) \right) + \beta \qquad \\ \\ \therefore v(t) = -C \frac{e^{-\alpha t}}{\alpha} \left(t + \frac{1}{\alpha} \right) + \beta \ .\qquad \qquad
# \end{aligned}
# \tag{1.4}
# $$

# %% [markdown]
# Para esse desenvolvimento, utilizamos o método da integração por partes. A constante $\beta$ que aparece em (1.4) é uma constante de integração. Para determiná-la, vamos utilizar nossa condição inicial, que nos informa que inicialmente, a partícula se encontra em repouso, ou seja, $v(0) = 0$. Aplicando, temos que:

# %% [markdown]
# $$
# v(0) = -C \frac{e^{-\alpha 0}}{\alpha} \left(0 + \frac{1}{\alpha} \right) + \beta = 0 \Rightarrow \frac{-C}{\alpha ^2} + \beta = 0 \Rightarrow \beta = \frac{C}{\alpha ^2}.
# $$

# %% [markdown]
# Assim, a função para a velocidade se torna:

# %% [markdown]
# $$
# v(t) = -\frac{C}{\alpha} \left( t e^{-\alpha t} + \frac{e^{-\alpha t}}{\alpha } - \frac{1}{\alpha} \right)\ .
# \tag{1.5}
# $$

# %% [markdown]
# Agora, estamos interessados em encontrar a função que descreve a posição da partícula em função do tempo. Considerando um movimento apenas no eixo $x$, a definição de velocidade é:

# %% [markdown]
# $$
# v = \frac{dx}{dt}.
# $$

# %% [markdown]
# Portanto, facilmente podemos obter que:

# %% [markdown]
# $$
# \int dx = \int v dt \rightarrow x(t) = \int v dt.
# $$

# %% [markdown]
# Subsituindo a função para a velocidade obtida em (1.5) nesta expressão, vamos encontrar que:

# %% [markdown]
# $$
# \begin{aligned}
# x = \int  -\frac{C}{\alpha} \left( t e^{-\alpha t} + \frac{e^{-\alpha t}}{\alpha } - \frac{1}{\alpha} \right)\ dt \Rightarrow x = -\frac{C}{\alpha} \left(\int t e^{-\alpha t} \ dt + \int \frac{e^{-\alpha t}}{\alpha } \ dt - \int \frac{1}{\alpha} \ dt \right) \\
# \\
# \Rightarrow x = -\frac{C}{\alpha} \left[ \left(\frac{te^{-\alpha t}}{-\alpha} + \frac{1}{\alpha} \left(\frac{e^{-\alpha t}}{-\alpha}\right) \right)  - \frac{e^{-\alpha t}}{\alpha^2} - \frac{t}{\alpha}\right] + P \qquad \qquad \qquad \\
# \\
# \therefore  \; x(t) = \frac{C}{\alpha^2} \left[ te^{-\alpha t} + \frac{2e^{-\alpha t}}{\alpha} + t \right] + P \ .\qquad \qquad \qquad \qquad \qquad
# \end{aligned}
# \tag{1.6}
# $$

# %% [markdown]
# Aqui, usamos novamente integração por partes. Alguns passos foram omitidos por semelhança para a dedução da função da velocidade. Para determinar a constante $P$, vamos utilizar novamente uma condição inicial. Vamos assumir que inicialmente, nossa partícula está na origem, ou seja, $x(0) = 0$. Substituindo essa informação, temos que:

# %% [markdown]
# $$
# x(0) = \frac{C}{\alpha^2} \left[ 0 e^{-\alpha 0} + \frac{2e^{-\alpha 0}}{\alpha} + 0 \right] + P = 0 \Rightarrow \frac{C}{\alpha^2}\left(\frac{2}{\alpha} \right) + P = 0 \Rightarrow P = -\frac{2C}{\alpha ^3}.
# $$

# %% [markdown]
# Com isso, a função da posição se torna:

# %% [markdown]
# $$
# x(t) = \frac{C}{\alpha^2} \left[ te^{-\alpha t} + \frac{2e^{-\alpha t}}{\alpha} + t - \frac{2}{\alpha} \right] = \frac{C}{\alpha^2} \left[ t \left(1 + e^{-\alpha t} \right) + \frac{2e^{-\alpha t}}{\alpha} - \frac{2}{\alpha} \right].
# \tag{1.7}
# $$

# %% [markdown]
# Como obtemos as três funções necessárias para constantes $C$ e $\alpha$ quaisquer, vamos substituir os valores fornecidos pela questão para delimitarmos nossas soluções:

# %% [markdown]
# $$
# \begin{aligned}
# x(t) =  \frac{1 \ m/s^3}{(0,5 \ s^{-1})^2} \left[ t \left(1 + e^{-0,5 \ s^{-1} \ t} \right) +  \frac{2 e^{-0,5 \ s^{-1} \ t}}{0,5 \ s^{-1}} - \frac{2}{0.5 \ s^{-1}}\right]  \Rightarrow x(t) =  4 \  m/s \left[t \left( 1 + e^{-0,5 t \ s^{-1}} \right) + 4 e^{-0,5 t \ s^{-1}} \ s - 4 \ s  \right] \\ \\
# v(t) =  -  \frac{1 \ m/s^3}{0,5 \ s^{-1}} \left(t e^{-0,5 \ s^{-1} \ t} + \frac{e^{-0,5 \ s^{-1} \ t}}{0,5 \ s^{-1}} - \frac{1}{0,5 s^{-1}}   \right)  \Rightarrow v(t) =  -  2 \ m/s^2 \left(\left(t + 2 \ s \right)e^{-0,5 \ s^{-1} \ t}  - 2 \ s   \right) \qquad \quad  \\ \\
# a(t) = (1 \ m/s^3) \ t e^{-0,5 \ s^{-1} \ t} \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad \qquad  \qquad
# \end{aligned}
# $$

# %% [markdown]
# Agora, vamos fazer todo o processo de visualização gráfica. Os comentários do código estarão descritos dentro das respectivas células.

# %%
#Aqui, definimos as constantes utilizadas no problema, nesse caso, C e alfa.
C = 1
alfa = 0.5

# %%
#Vamos definir arrays, onde iremos alocar aceleração, velocidade e posição:
ax,vx,xp = [],[],[]

# %%
#Aqui, vamos definir a função da aceleração em função do tempo:
def a(t):
    return C * t * np.exp(-alfa*t)

# %%
#Vamos definir o tempo inicial e final:
t1,t2 = 0,10
N = 10000 #Sub-intervalos de tempo para calcular as iterações
tempo = np.linspace(t1,t2,N) #Função que irá ajudar a calcular cada ponto no tempo.

# %%
#Faremos o preenchimento do array com um laço 'for'. Simultaneamente, armazenaremos os dados da aceleração.
for t in tempo:
    ax.append(a(t))

# %%
#Agora, vamos 'plotar' o gráfico obtido:
plt.figure(figsize=(6, 4))
plt.plot(tempo,ax)
plt.xlabel("t (s)")
plt.ylabel("a (m/s²)")
plt.title("Aceleração - Questão 1")
plt.grid()
plt.show()

# %%
#Faremos o mesmo, agora para a velocidade. Vamos definir a função, da mesma forma que consta em (5):
def v(t):
    aux = t* np.exp(-alfa*t)+ np.exp(-alfa*t)/alfa - 1/alfa
    return (-C/alfa)* aux

# %%
#Preencher o array referente à velocidade:
for t in tempo:
    vx.append(v(t))

# %%
#Agora, vamos 'plotar' o gráfico obtido:
plt.figure(figsize=(6, 4))
plt.plot(tempo,vx)
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")
plt.title("Velocidade - Questão 1")
plt.grid()
plt.show()

# %%
#Por fim, vamos repetir o procedimento para o gráfico da posição. Definimos a função, como consta em (7):
def x(t):
    aux = t* np.exp(-alfa*t) + 2*np.exp(-alfa*t)/alfa + t - 2/alfa
    return (C/alfa**2)*aux

# %%
#Preencher o array referente à posição:
for t in tempo:
    xp.append(x(t))

# %%
#Agora, vamos 'plotar' o gráfico obtido:
plt.figure(figsize=(6, 4))
plt.plot(tempo,xp)
plt.xlabel("t (s)")
plt.ylabel("x (m)")
plt.title("Posição - Questão 1")
plt.grid()
plt.show()

# %% [markdown]
# Analisando os gráficos, notamos um comportamente curioso para a velocidade e a posição: ambas crescem indefinidamente no tempo. Porém, isso é óbvio quando notamos que a força que age sobre a partícula é sempre positiva para $t > 0$. Logo, a aceleração sempre será positiva, que implica no estado crescente da velocidade. Por sua vez, esse estado implica no crescimento indefinido para a posição. Dessa forma, se nenhuma outra força impedir o movimento da partícula, ela partirá para o infinito.

# %% [markdown]
# ## Problema 2

# %% [markdown]
# **Movimento vertical com resistência de uma partícula.** Uma partícula de massa 𝑚 está submetida ao movimento vertical em um determinado meio com uma força de retardo proporcional a velocidade.
#
# **Objetivo**: Vamos achar como deve ser a trajetória de uma partícula sobre duas forças: a gravitacional e uma força de arrasto, proporcional à velocidade. Posteriormente, faremos gráficos para analisar a trajetória e velocidade da partícula para alguns casos específicos.

# %% [markdown]
# $$
# y(t) = -\frac{1}{K}\left(\left(v_0 + \frac{g}{K} \right) e^{-Kt} - \left(v_0 + \frac{g}{K} \right) + gt \right)
# $$

# %% [markdown]
# $$
# v(t) = \left(v_0 + \frac{g}{K}\right) e^{-Kt} - \frac{g}{K}
# $$

# %%
g= const.g
k = 5e-1
tempo = np.linspace(0,10,2000)

# %%
def y(t,v):
    y = (-1/k)*((v + (g/k))*np.exp(-k*t) + g*t -25e1*k - (v + (g/k)))
    return y

# %%
def vy(t,v):
    vy = (v + (g/k))*np.exp(-k*t) - (g/k)
    return vy

# %%
vt = np.array([0, -g/(3*k), (3/2)*(-g/k)])
plt.figure(figsize=(6, 4))
for v in vt:
    yt=[]
    for t in tempo:
        yt.append(y(t,v))
    plt.plot(tempo, yt, label=f"v = {v:.2f}")
plt.xlabel("Tempo (s)")
plt.ylabel("y (m)")
plt.ylim(0,250)
plt.title("Posição - Questão 2")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
for v in vt:
    vp=[]
    for t in tempo:
        vp.append(vy(t,v))
    plt.plot(tempo, vp, label=f"v = {v:.2f}")
plt.xlabel("Tempo (s)")
plt.ylabel("v (m/s)")
plt.title("Velocidade - Questão 2")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Problema 3

# %% [markdown]
# Quadrática:

# %% [markdown]
# $$
# v(t) = -\sqrt{\frac{mg}{K}} \tanh{\left(t \sqrt{\frac{kg}{m}} \right)}
# $$

# %% [markdown]
# Linear:

# %% [markdown]
# $$
# v(t) = \left(v_0 + \frac{g}{K}\right) e^{-Kt} - \frac{g}{K}
# $$

# %%
k = 2e-1
m = 1

# %%
def v_linear(t):
    ct = g/k
    return ct*np.exp(-k*t) - ct

# %%
def v_quad(t):
    return -np.sqrt(m * g / k) * np.tanh(np.sqrt(k * g / m) * t)

# %%
v1,v2 =[],[]
ti, tf = 0, 35
t1,t2 = 20,30
tempo = np.linspace(ti,tf,2000)

# %%
for t in tempo:
    v1.append(v_linear(t))
    v2.append(v_quad(t))

# %%
plt.figure(figsize=(6, 4))
plt.plot(tempo, v1, label = "Força linear")
plt.plot(tempo,v2, label = "Força quadrática")
plt.xlabel("Tempo (s)")
plt.ylabel("x (m)")
plt.title("Velocidade - Questão 3")
plt.grid()
plt.legend(loc="best")
plt.show()

# %%
vlt1 = v_linear(t1)
vlt2 = v_linear(t2)
vlt1,vlt2
# Out:
# (-48.13517469945897, -48.91170872483347)

# %%
vqt1 = v_quad(t1)
vqt2 = v_quad(t2)
vqt1,vqt2
# Out:
# (-7.002374597234855, -7.002374597234855)

# %%
vtl = g/k
vtq = np.sqrt(g/k)
vtl,vtq
# Out:
# (49.033249999999995, 7.002374597234855)

# %% [markdown]
# ## Problema 4

# %% [markdown]
# **Movimento de projéteis.** Considere o movimento de um projétil em duas dimensões com velocidade inicial $v_0$ e o ângulo de inclinação $\theta$.

# %% [markdown]
# **Objetivo:** Vamos utilizar a segunda Lei de Newton para buscar equações diferenciais que governem as trajetórias de um lançamento oblíquo, considerando ou não a resistência do ar. Além disso, vamos mostrar como o coeficiente de arrasto influencia no alcance do projétil.

# %% [markdown]
# **Desenvolvimento teórico:**  Como a questão pede resultados distintos para cada item, vamos separar nosso desenvolvimento teórico (e os códigos apropriados) para cada item separadamente.

# %% [markdown]
# #### a) Calcule o deslocamento $y(t)$, a velocidade $v(t)$ e o alcance do projetil sem considerar o efeito resistivo do ar.

# %% [markdown]
# Esse é um problema clássico da cinemática. Usaremos o método de resoluções por equações diferenciais para construirmos uma leve base para o item b). Vamos aplicar a segunda Lei de Newton para cada uma das coordenadas separadamente. Vamos considerar o eixo $x$ como positivo para a direita e o eixo $y$ como positivo para cima. Sabendo que temos força atuando apenas no eixo $y$ (que será a força gravitacional), escrevemos o seguinte:

# %% [markdown]
# $$
# m\ddot{x} = 0 \Rightarrow \ddot{x} = 0
# \tag{4.1}
# $$

# %% [markdown]
# $$
# m\ddot{y} = -mg \Rightarrow \ddot{y} = -g
# \tag{4.2}
# $$

# %% [markdown]
# Nosso objetivo agora é resolver as equações (4.1) e (4.2), encontrando assim o movimento descrito pelo projétil. Vamos começar pela equação (4.1). Não é preciso nenhum aprofundamento matemático para notar que sua solução é a equação de uma reta, na forma:

# %% [markdown]
# $$
# x(t) = m t + b,
# $$

# %% [markdown]
# onde $m$ e $b$ são constantes a determinar pelas condições de contorno. Estaremos considerando que, no instante inicial ($t = 0$), o projétil estará na origem e sua velocidade inicial é $v_0$. Além disso, dizemos que o projétil é lançado a partir de um ângulo $\theta$ em relação a horizontal. Pela primeira condição, obteremos:

# %% [markdown]
# $$
# x(0) = 0 \Rightarrow m \cdot 0 + b = 0 \Rightarrow b = 0.
# $$

# %% [markdown]
# Para determinarmos a constante $m$, vamos lembrar que a velocidade inicial na direção de $x$ será a projeção da velocidade inicial no respectivo eixo. Nesse caso, teremos que:

# %% [markdown]
# $$
# \dot{x}(t) = m \; ;  \; \dot{x}(0) = v_0\cos{(\theta)} \therefore m = v_0\cos{(\theta)}.
# $$

# %% [markdown]
# Com as constantes determinadas, podemos escrever nossa função $x(t)$ adequadamente como:

# %% [markdown]
# $$
# x(t) = v_0\cos{(\theta)} t
# \tag{4.3}
# $$

# %% [markdown]
# Agora, buscaremos resolver (4.2). Vamos escrever a equação como:

# %% [markdown]
# $$
# \frac{d}{dt}\left(\frac{dy}{dt} \right) = -g.
# $$

# %% [markdown]
# Porém, o termo entre parênteses é exatamente a velocidade no eixo $y$, $v_y(t)$. Subsituindo, teremos:

# %% [markdown]
# $$
# \frac{d  v_y(t)}{dt} = -g.
# $$

# %% [markdown]
# Integrando ambos os lados com relação ao tempo:

# %% [markdown]
# $$
# \int \frac{dv_y(t)}{dt} \ dt = \int -g \ dt \Rightarrow v_y(t) = -gt + A,
# \tag{4.4}
# $$

# %% [markdown]
# onde $A$ é uma constante a determinar pelas condições de contorno. Faremos essa determinação posteriormente. Agora que temos uma expressão para a velocidade, devemos integrá-la com relação ao tempo para obtermos a função da posição:

# %% [markdown]
# $$
# y(t) = \int v_y(t) \  dt \Rightarrow y(t) = \int (-gt + A) \  dt \Rightarrow y(t) = -\frac{gt^2}{2} + At + B,
# \tag{4.5}
# $$

# %% [markdown]
# onde $B$ é outra constante, que determinaremos também pelas condições de contorno do problema. Vamos aplicar tais condições para escrever a solução de forma geral. Primeiro, lembremos que o projétil está inicialmente na origem, logo:

# %% [markdown]
# $$
# y(0) = 0 \Rightarrow -\frac{g \cdot 0^2}{2} + A \cdot 0 + B = 0 \therefore B = 0.
# $$

# %% [markdown]
# Além disso, vamos usar que a velocidade inicial no eixo $y$ é a projeção da velocidade inicial no respectivo eixo. Substituindo essa afirmação na equação (4.4):

# %% [markdown]
# $$
# v_y(0) = v_0\sin{(\theta)} \Rightarrow -g \cdot 0 + A = v_0\sin{(\theta)} \therefore A = v_0\sin{(\theta)}.
# $$

# %% [markdown]
# Substituindo as constantes em (4.5), finalmente obtemos nossa equação para o movimento na direção $y$:

# %% [markdown]
# $$
# y(t) = v_0\sin{(\theta)}t - \frac{gt^2}{2}.
# \tag{4.6}
# $$

# %% [markdown]
# As equações (4.3) e (4.6) descrevem a posição do projétil durante o lançamento. Além disso, a equação (4.4) em conjunto da velocidade em $x$ ser constante nos dá a função da velocidade. Escrevendo como funções vetoriais, teremos:

# %% [markdown]
# $$
# \begin{aligned}
# \vec{r}(t) = \left(v_0\cos{(\theta)} t\right)\hat{i} + \left(v_0\sin{(\theta)}t - \frac{gt^2}{2}\right)\hat{j} \\ \\
# \dot{\vec{r}}(t) = \vec{v}(t) = \left(v_0\cos{(\theta)} \right) \hat{i} + \left(v_0\sin{(\theta)} - gt \right)\hat{j}
# \end{aligned}
# $$

# %% [markdown]
# Nos resta a tarefa de encontrarmos o alcance máximo para esse lançamento. Para acharmos o alcance, devemos obter o valor para $x(t)$ no tempo em que $y = 0$ na equação (4.6). Em outras palavras, queremos saber quanto tempo leva para que a posição em $y$ do projétil seja nulo. Isso significa que o objeto retornou ao chão, logo isso demarcará a maior distância que o mesmo pode atingir. Em termos matemáticos, temos que:

# %% [markdown]
# $$
# y(t) = 0 \Rightarrow v_0\sin{(\theta)}t - \frac{gt^2}{2} = 0 \Rightarrow t\left(v_0\sin{(\theta)} - \frac{gt}{2} \right) = 0.
# $$

# %% [markdown]
# Para que essa expressão seja verdadeira, ou $t = 0$, ou todo o termo entre parênteses é nulo. Porém, $t=0$ não é agradável, pois indica justamente o instante inicial do lançamento. Além disso, para esse valor de tempo, $x = 0$, o que não é desejável. Sendo assim, o tempo em que o projétil alcança sua maior distância éstá relacionado da seguinte maneira:

# %% [markdown]
# $$
# v_0\sin{(\theta)} - \frac{gt}{2} = 0 \Rightarrow t = \frac{2 v_0\sin{(\theta)}}{g}.
# $$

# %% [markdown]
# Agora que achamos o tempo necessário, vamos calcular finalmente o alcance em si. Substituindo $t$ na equação (4.3), e renomeando $x$ para $R$, teremos:

# %% [markdown]
# $$
# R = v_0\cos{(\theta)}\frac{2 v_0\sin{(\theta)}}{g} \Rightarrow R = \frac{v^2_0}{g}(2\cos{(\theta)}\sin{(\theta)}).
# $$

# %% [markdown]
# Para simplificarmos a expressão, podemos lembrar de uma identidade trigonométrica:

# %% [markdown]
# $$
# \sin{(2 \alpha)} = \sin{(\alpha)}\cos{(\alpha)} + \cos{(\alpha)}\sin{(\alpha)} = 2\sin{(\alpha)}\cos{(\alpha)}
# $$

# %% [markdown]
# Substituindo esse resultado para o termo entre parênteses, obtemos que o alcance em um lançamento oblíquo sem resistência do ar é:

# %% [markdown]
# $$
# R = \frac{v^2_0 \sin{2 \theta}}{g}
# \tag{4.7}
# $$

# %% [markdown]
# #### b) Calcule o deslocamento, a velocidade e a redução do alcance do projetil devido à ação de uma força resistiva provocada pela resistência do ar diretamente proporcional à velocidade do projétil

# %% [markdown]
# Para esse item, faremos uma análise inicial parecida com o item anterior. Entretanto, a forma da equação resultante mudará o processo para resolvermos a equação de movimento. Primeiro de tudo, é importante notar que, se a força é diretamente proporcional à velocidade do objeto, podemos escrever suas componentes da seguinte forma:

# %% [markdown]
# $$
# \vec{F}_a = -k(\dot{x}\hat{i} + \dot{y}\hat{j}),
# $$

# %% [markdown]
# onde $k$ é o coeficiente da força de arrasto, uma constante positiva. O sinal negativo indica que a força de arrasto tem sempre direção oposta à velocidade do objeto. Se tomarmos o módulo dessa força, obtemos:

# %% [markdown]
# $$
# |\vec{F}| = \sqrt{k^2(\dot{x}^2 + \dot{y}^2)} = k\sqrt{v^2} \Rightarrow |\vec{F}| = kv.
# $$

# %% [markdown]
# Logo, se a força de arrasto for definida como anteriormente, ela será proporcional à velocidade do projétil.

# %% [markdown]
# Agora, vamos trabalhar com as equações de movimento. Temos que utilizar a segunda Lei de Newton novamente. Vamos considerar nosso sistema de coordenadas idêntico ao que usamos no item a). Sabemos que, no eixo $x$, a única força que atua sobre a partícula é a força de arrasto. Dessa forma, podemos escrever que:

# %% [markdown]
# $$
# m\ddot{x} = - k \dot{x} \Rightarrow \ddot{x} + \frac{k}{m}\dot{x} = 0 \Rightarrow \ddot{x} +\beta \dot{x} = 0,
# \tag{4.8}
# $$

# %% [markdown]
# onde definimos $\beta = k/m$. Essa é uma equação diferencial ordinária homogênea de segunda ordem. Vamos aplicar a mesma ideia para o eixo $y$. Entretando, devemos lembrar que além da força de arrasto, o projétil fica sujeito à força gravitacional nessa direção. Assim, escrevemos:

# %% [markdown]
# $$
# m\ddot{y} = -k\dot{y} - mg \Rightarrow \ddot{y} + \beta \dot{y} = -g.
# \tag{4.9}
# $$

# %% [markdown]
# Esta é uma equação diferencial ordinária de segunda ordem, porém, não homogênea.

# %% [markdown]
# Para encontrarmos por completo a trajetória do projétil, devemos resolver as equações (4.8) e (4.9) e aplicar as condições de contorno, que serão as mesmas do item a). O método de resolução das EDO's se darão através do polinômio característico e outras técnicas que serão explicadas a seguir.

# %% [markdown]
# Primeiro, vamos resolver a equação que diz respeito à trajetória no eixo $x$. Usando o polinômio característico, temos que:

# %% [markdown]
# $$
# \begin{aligned}
# \lambda ^2 + \beta \lambda = 0 \Rightarrow \lambda(\lambda + \beta) = 0 \\ \\
# \therefore \quad \lambda_1 = 0 \ ; \ \lambda_2 = -\beta. \quad \ \
# \end{aligned}
# $$

# %% [markdown]
# De acordo com o método, a solução geral para (4.8) será:

# %% [markdown]
# $$
# x(t) = Ae^{\lambda_1 t} + Be^{\lambda_2 t} \Rightarrow x(t) = A + B e^{-\beta t}
# \tag{4.10}
# $$

# %% [markdown]
# Aplicando as condições de contorno, devemos ter:

# %% [markdown]
# $$
# \begin{aligned}
# x(0) = 0 \Rightarrow A + Be^{\beta \cdot 0} = 0 \Rightarrow A = - B \qquad \qquad \quad \\ \\
# \dot{x}(0) = v_0 \cos{(\theta)} \Rightarrow -\beta B e^{-\beta \cdot 0} = v_0 \cos{(\theta)} \therefore B = -\frac{v_0 \cos{(\theta)}}{\beta} \\ \\
# \Rightarrow A = \frac{v_0 \cos{(\theta)}}{\beta} \qquad \qquad \qquad \qquad \qquad
# \end{aligned}
# $$

# %% [markdown]
# Agora que achamos as constantes, vamos substituí-las na expressão (4.10), colocar o termo padrão em evidência para escrevermos a função da posição no eixo $x$ como:

# %% [markdown]
# $$
# x(t) = \frac{ v_0 \cos{(\theta)}}{\beta} \left(1 - e^{-\beta t}  \right).
# \tag{4.11}
# $$

# %% [markdown]
# Devemos fazer um processo análogo para a equação (4.9). Entretanto, ela não se trata de uma EDO homogênea. Sendo assim, devemos buscar uma solução geral que seja a soma de duas funções: uma função que resolva a EDO, porém considerando-a homogênea (vamos chamar de solução da homogênea), ou seja, descartamos o termo fonte; e uma solução particular, em outras palavras, uma função que ao ser substituída diretamente em (4.9), gera o resultado (nesse caso, $-g$). Para a solução particular, utilizaremos o método dos coeficientes a determinar, que será mostrado com calma posteriormente.

# %% [markdown]
# Primeiro, vamos buscar a solução homogênea. Então, vamos resolver:

# %% [markdown]
# $$
# \ddot{y} + \beta \dot{y} = 0.
# $$

# %% [markdown]
# Mas essa é uma EDO idêntica a expressão (4.8). Logo, suas soluções devem ser iguais, exceto pelas constantes, que determinaremos pelas condições de contorno. Assim, nossa função pode ser escrita como:

# %% [markdown]
# $$
# y(t) = P e^{-Kt} + Q + f(t),
# \tag{4.12}
# $$

# %% [markdown]
# onde $P$ e $Q$ são constantes, determinadas pelas condições de contorno e $f(t)$ é a nossa solução particular que iremos buscar.

# %% [markdown]
# Para achar $f(t)$, vamos usar os métodos dos coeficientes a determinar. Assim, devemos pensar em funções parecidas com aquela que faz a EDO deixar de ser homogênea (o termo fonte, no caso, $-g$), fazer uma combinação linear destas, substituir na equação e determinar quais constantes devem acompanhá-las para que a igualdade seja mantida. Como o termo fonte da equação (4.9) é uma função polinomial (de ordem zero), e as derivadas são de, no máximo, segunda ordem, vamos buscar uma solução particular como uma combinação linear de polinômios de primeiro e segundo grau. Em outras palavras, vamos buscar nossa função na forma: $f(t) = \alpha t^2 + \eta t$.

# %% [markdown]
# Note que não incluímos um polinômio de grau zero, ou seja, um termo constante. Isso acontece pois a expressão (4.9) envolve apenas derivadas de $y$. Nesse caso, o termo não influenciará em nada para descobrirmos nossa solução particular. Além de tudo isso, a solução da homogênea já envolve uma constante. Se a solução particular tiver outro termo aditivo constante, ele se juntará à constante $Q$ e formará outra, que seria determinada pelas condições de contorno. Entretanto, vamos apenas ignorar o polinômio de grau zero na solução particular para simplificação. Substituindo $f(t)$ proposta na EDO para $y$, teremos:

# %% [markdown]
# $$
# \frac{d^2}{dt^2}(\alpha t^2 + \eta t) + \beta \frac{d}{dt}(\alpha t^2 + \eta t) = -g \Rightarrow 2 \alpha + \beta(2 \alpha t + \eta) = -g \Rightarrow 2 \alpha \beta t + (2 \alpha + \beta \eta) = -g.
# $$

# %% [markdown]
# Note que, em um lado da igualdade, existe um termo envolvendo $t$, enquanto o outro não tem. Além disso, existe um termo independente da variável $t$ em cada lado da equação. Para a expressão ser verdadeira, devemos ter que:

# %% [markdown]
# $$
# \begin{aligned}
# 2 \alpha \beta t = 0 \quad \\ \\
# 2 \alpha + \beta \eta = -g
# \end{aligned}
# $$

# %% [markdown]
# Resolvendo o sistema, obtemos que:

# %% [markdown]
# $$
# \begin{aligned}
# \alpha = 0 \qquad \qquad \\ \\
# \beta \eta = -g \Rightarrow \eta = -\frac{g}{\beta}
# \end{aligned}
# $$

# %% [markdown]
# E assim, nossa solução particular se torna, finalmente: $f(t) = -gt/\beta$.

# %% [markdown]
# Subsituindo essa informação em (4.12), finalmente obtemos nossa solução geral para o movimento no eixo $y$:

# %% [markdown]
# $$
# y(t) = P e^{-\beta t} + Q - \frac{gt}{\beta}.
# \tag{4.13}
# $$

# %% [markdown]
# Para determinarmos completamente a solução, vamos aplicar as condições de contorno. Elas são as mesmas que usamos no item a). Sendo assim, teremos:

# %% [markdown]
# $$
# \begin{aligned}
# y(0) = 0 \Rightarrow P e^{- \beta 0} + Q - \frac{0g}{K} = 0 \Rightarrow P + Q = 0 \Rightarrow P = - Q
# \end{aligned}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# \dot{y}(0) = v_0\sin{(\theta)} \Rightarrow -\beta P e^{-K0} + 0 - \frac{g}{\beta} = v_0\sin{(\theta)} \Rightarrow \beta P + \frac{g}{\beta} = - v_0\sin{(\theta)} \\ \\
# \therefore \ P = -\frac{1}{\beta}\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right) \; \Rightarrow \; Q = \frac{1}{\beta}\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right). \qquad \qquad
# \end{aligned}
# $$

# %% [markdown]
# Agora que temos nossas constantes, podemos escrever nossa equação (4.13) que resolve por completo o problema:

# %% [markdown]
# $$
# \begin{aligned}
# y(t) = -\frac{1}{\beta}\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right) e^{-\beta t} + \frac{1}{\beta}\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right) - \frac{gt}{\beta} \\ \\
# \Rightarrow \; y(t) = \frac{1}{\beta}\left(\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right)(1 - e^{-\beta t}) - gt \right). \qquad
# \end{aligned}
# \tag{4.14}
# $$

# %% [markdown]
# Finalmente, podemos expressar nosso vetor posição em notação vetorial como:

# %% [markdown]
# $$
# \vec{r}(t) = \left(\frac{ v_0 \cos{(\theta)}}{\beta} \left(1 - e^{-\beta t}  \right)\right)\hat{i} + \frac{1}{\beta}\left(\left(v_0\sin{(\theta)} + \frac{g}{\beta} \right)\left(1 - e^{-\beta t}\right) - gt \right)\hat{j}
# \tag{4.15}
# $$

# %% [markdown]
# Para acharmos a velocidade, basta derivarmos nosso vetor posição, que obteremos:

# %% [markdown]
# $$
# v(t) = \dot{\vec{r}}(t) = \left(v_0 \cos{(\theta)}e^{-\beta t}\right)\hat{i} + \left(\left(v_0\sin{(\theta)} + \frac{g}{\beta}\right) e^{-\beta t} - \frac{g}{\beta}\right)\hat{j}
# \tag{4.16}
# $$

# %% [markdown]
# Precisamos agora, achar apenas um método de calcular a redução do alcance para o lançamento que sofre resistência do ar. Para isso, vamos utilizar uma abordagem parecida para o problema em que desprezamos a resistência do ar: vamos encontrar um tempo $t \neq 0$ para que o valor de $y(t)$ seja nulo. Igualando (4.14) a $0$ e rearranjando os termos, obtemos:

# %% [markdown]
# $$
# t = \left(v_0\sin{(\theta)} + \frac{g}{\beta} \right)\left(\frac{1 - e^{-\beta t}}{g}\right).
# $$

# %% [markdown]
# O problema é que essa é uma equação transcendental e não pode ser resolvida analiticamente em $t$, da maneira que ela está. Podemos utilizar métodos numéricos para encontrar os valores de tempo e então subsituir na expressão (4.11) para determinarmos o alcance. Alcancaríamos uma precisão incrível, porém, estamos interessados em encontrar alguma expressão analítica para analisarmos. Para isso, devemos utilizar o método da pertubação (utilizado no exemplo 2.7 no livro do Marion), considerando $k$ um valor muito pequeno. O valor encontrado para o tempo é:

# %% [markdown]
# $$
# t \simeq \frac{2 v_0\sin{(\theta)}}{g}\left(1 - \frac{\beta v_0\sin{(\theta)}}{3g} \right).
# $$

# %% [markdown]
# Subsituindo o valor de $t$ em (4.11) e expandindo a expressão em sua série de Taylor, encontramos o valor para o alcance $R^{\prime}$ considerando a resistência do ar:

# %% [markdown]
# $$
# R^{\prime} \simeq R\left(1 - \frac{4 \beta v_0 \sin{(\theta)}}{3g} \right),
# $$

# %% [markdown]
# onde $R$ representa o alcance se desconsiderarmos a resistência do ar. Fazendo a diferença entre o alcance sob efeito da força de arrasto e do alcance sem sofre o efeito, obtemos:

# %% [markdown]
# $$
# \Delta R = R^{\prime} - R = R\left(1 - \frac{4 \beta v_0 \sin{(\theta)}}{3g} -1 \right) \Rightarrow \Delta R = -R\left(\frac{4 \beta v_0 \sin{(\theta)}}{3g} \right).
# \tag{4.17}
# $$

# %% [markdown]
# Note que a diferença entre os alcances é um valor sempre negativo, o que é esperado, visto que a força de retardo impede que a partícula mantenha velocidades altas. Entretanto, é importante ressaltar que esse resultado só é valido para a restrição:

# %% [markdown]
# $$
# \beta \ll \frac{g}{v_0\sin{(\theta)}},
# $$

# %% [markdown]
# visto que devemos considerar valores muito pequenos para que as expansões se mantenham apenas em termos simples.

# %% [markdown]
# #### c) Considerando os resultados anteriores. Faça gráficos da altura vertical em função do alcance para diferentes valores da constante da força de retardo $k$ = 0, 0.005, 0.01, 0.02, 0.04, 0.06, 0.08 e 0.1.

# %%
#Primeiramente, vamos delimitar as constantes utilizadas: massa da partícula, velocidade inicial e ângulo de lançamento. 
m = 1
v0 =150
theta = 30
#Agora, utilizamos as relações trigonométricas para escrever a velocidade em cada eixo.
v0x = v0*np.cos(theta*np.pi/180)
v0y = v0*np.sin(theta*np.pi/180)

# %%
#Definimos a função da trajetória, idêntica à encontrada na expressão (4.15)
def r(t,k):
    #Definimos a constante beta como a divisão do coeficiente de arrasto pela massa, assim como fizemos em nossa dedução:
    beta = k/m
    x = v0x/beta * (1- np.exp(-beta*t))
    y = (-1/beta)*((v0y+(g/beta))*np.exp(-beta*t) + g*t - (v0y+(g/beta)))
    return np.array([x,y])

# %%
#Aqui, escolhemos os tempos iniciais e finais de nossa simulação
t1,t2 = 0, 20
#Agora, fazemos uma divisão entre os tempos para calcularmos nossa trajetória em cada ponto
tempo = np.linspace(t1,t2,1000)

# %%
#Escrevemos  o conjunto de coeficientes da força de arrastos pedido pela questão em forma de um vetor, para que a iteração fique simplificada.
K = np.array([0.0000001, 0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.1])
#Importante notar que, como nossa função apresenta operações de divisão, onde a constante de arrasto se encontra no denominadaor, não podemos atribuir
#a ela o valor 0 propriamente. Em seu lugar, usamos um número muito pequeno, que não cause instabilidades numéricas, para fazer o papel do 0.

# %%
#Definimos um vetor nulo para representar o alcance da partícula em cada caso.
alc=[]

# %%
#Aqui definimos as dimensões da imagem
plt.figure(figsize=(6, 4))
#Utilizamos um laço para calcular sobre todos os valores do coeficiente de arrasto
for k in K:
    #Iniciamos vetores nulos para cada valor de k, para guardarmos as trajetórias
    xt,yt=[],[]
    #Utilizamos um laço para calcular a trajetória para cada tempo. Armazenamos nos vetores adequadamente
    for t in tempo:
        xt.append(r(t,k)[0])
        yt.append(r(t,k)[1])
        #Aqui, usamos a condição de parada. Se o valor de y for inferior a zero, isso significa que nosso projétil já alcançou o solo,
        #com isso, devemos interromper as iterações.
        if r(t,k)[1] < 0:
            #Com o oprojétil ao solo, significa que achamos a distância correspondente ao alcance máximo. Com isso, preenchemos o vetor
            #correspondente ao alcance pelo valor da direção x no instante em que o objeto toca no chão.
            alc.append(r(t,k)[0])
            break
    #Fazemos um gráfico para cada trajetória, dependendo do valor de k.
    plt.plot(xt,yt, label = f"k ={k:.2f}")
#Fazemos o gráfico de todas as trajetórias juntas em uma única imagem.
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.legend(loc="best")
plt.title("Trajetórias para diferentes valores do coeficiente de arrasto")
plt.xlim(0,2300)
plt.grid()
plt.show()

# %% [markdown]
# #### d) Considerando os resultados anteriores. Faça gráficos do alcance em função dos diferentes valores da constante da força de retardo $k$ = 0, 0.005, 0.01, 0.02, 0.04, 0.06, 0.08 e 0.1.

# %%
#Essa parte se torna fácail, visto que no item anterior, estrategicamente guardamos os valores do alcance para cada lançamento, e portanto,
#para cada valor da constante de arrasto. Agora, basta fazermos o gráfico dessa relação

#Primeiro fazemos um gráfico de linha, unindo todos os resultados para enxergarmos mais facilmente uma "tendência" 
plt.plot(K,alc)
#Depois, explicitamos no gráfico o valor especificado de cada alcance, para efeitos de visualização
plt.plot(K,alc, 'o', color ="orange")
#E apresentamos a devida imagem.
plt.xlabel("k")
plt.ylabel("Alcançe (m)")
plt.title("Alcance em função do coeficiente k:")
plt.grid()
plt.show()

# %% [markdown]
# É importante notar que, se tivéssemos maiores valores de $k$ e uma grande quantidade desses coeficientes, poderíamos fazer um gráfico bem suave e determinar uma linha de tendência que se ajustasse adequadamente a todos os pontos. Além disso, poderíamos buscar funções matemáticas que se adequaria bem ao resultado.

# %% [markdown]
# Por fim, podemos observar que a constante da força de retardo possui papel fundamental na trajetória de cada lançamento, como era esperado. Pela visualização dos gráficos, é notório que ao aumentarmos o coeficiente de arrasto, diminuimos bruscamente o alcance em que o projétil pode alcançar. Além disso, vemos que a altura máxima atingida reduz significativamente com o aumento dessa constante. Assim, concluímos que ao tentarmos nos aproximar da realidade, mais complexo se torna o nosso problema físico.

# %% [markdown]
# ## Problema 5

# %% [markdown]
# **Energia potencial.** Uma partícula de massa $𝑚$ se movimentando em uma dimensão tem energia potencial
# $$
# U(x) = U_0 \left[2 \left(\frac{x}{a} \right)^2 - \left(\frac{x}{a} \right)^4 \right],
# $$
# onde $U_0$ e $a$ são constantes positivas.

# %% [markdown]
# **Objetivo**: Vamos utilizar as relações entre força e energia potencial para acharmos algumas relações importantes para o movimento da partícula sujeita ao potencial referido. Além disso, utilizaremos conceitos de energia mecânica para obter outros dados sobre o nosso sistema.

# %% [markdown]
# **Desenvolvimento teórico:** Como a questão pede resultados distintos para cada item, vamos separar nosso desenvolvimento teórico (e os códigos apropriados) para cada item separadamente.

# %% [markdown]
# #### a) Determine a força $𝐹(𝑥)$ atuando sobre a partícula.

# %% [markdown]
# Existe uma relação muito importante na física, que relaciona a força com a energia potencial de um certo sistema. Dizemos que a força é conservativa quando esta pode ser expressa como o gradiente da energia potencial $U$, ou seja:

# %% [markdown]
# $$
# \vec{F} = - \nabla U.
# \tag{5.1}
# $$

# %% [markdown]
# Essa relação nos diz que se conhecemos um certo potencial, podemos definir unicamente uma força referente ao devido sistema. Para o caso unidimensional, no qual o problema se trata, podemos transformar a equação (5.1) para:

# %% [markdown]
# $$
# F(x) = -\frac{dU(x)}{dx}.
# \tag{5.2}
# $$

# %% [markdown]
# Note que abandonamos a forma vetorial pois estamos trabalhando apenas em uma direção, não sendo necessário o uso dos versores unitários. Para determinarmos a força atuante na partícula imersa sobre o potencial referido na questão, basta tomarmos o negativo de sua derivada, como manda a equação (5.2):

# %% [markdown]
# $$
# \begin{aligned}
# F(x) = - \frac{d}{dx}\left(U_0 \left[2 \left(\frac{x}{a} \right)^2 - \left(\frac{x}{a} \right)^4 \right]\right) \Rightarrow F(x) = -U_0\left[\frac{4}{a} \left(\frac{x}{a} \right) - \frac{4}{a}\left(\frac{x}{a} \right)^3 \right] \\ \\
# \Rightarrow F(x) -\frac{4 U_0}{a}\left(\frac{x}{a} \right)\left[1 -  \left(\frac{x}{a} \right)^2\right]. \qquad \qquad \qquad \qquad
# \end{aligned}
# \tag{5.3}
# $$

# %% [markdown]
# #### b) Faça um gráfico de $𝑈(𝑥)$. Determine as posições de equilíbrio estável e instável.

# %% [markdown]
# Primeiramente vamos plotar o gráfico da energia potencial da partícula, utilizando $U_0 = 3 \ J$ e $a = 2 \ m$. Os comentários para a reprodução do gráfico estarão dispostos nas respectivas células.

# %%
#Definição das constantes do problema
a = 2
U0 = 3

# %%
#Aqui, reproduzimos a fórmula do potencial para que possamos calculá-lo para qualquer valor de x:
def U(x):
    r1 = 2*((x/a)**2)
    r2 = (x/a)**4
    return U0*(r1-r2)

# %%
#Definimos um vetor para os valores de x
X = np.linspace(-3,3,1000)
#E outro para guardar os valores da energia potencial
u = []

# %%
#Preenchemos o vetor do potencial a partir da definição da função, para cada valor de x determinado anteriormente
for x in X:
    u.append(U(x))

# %%
#Utilizamos um comando padrão para exibir o gráfico
plt.plot(X,u)
plt.xlabel("x (m)")
plt.ylabel("Potencial (J)")
plt.title("Potencial - Questão 5")
plt.grid()
plt.show()

# %% [markdown]
# Agora, vamos determinar analiticamente as posições de equilíbrio. Uma posição de equilíbrio pode ser definida como a posição em que a força resultante sobre a partícula seja nula (ou que a derivada do potencial seja nula, que são coisas equivalentes). Para isso, vamos usar a expressão (5.3) encontrada no item a) para a força e determinais para quais valores de $x$ a força se anula. Assim, escrevemos:

# %% [markdown]
# $$
# F(x) =  0 \Rightarrow -\frac{4 U_0}{a} \left[\left(\frac{x}{a} \right) - \left(\frac{x}{a} \right)^3 \right] = 0.
# $$

# %% [markdown]
# É fácil observar que essa expressão se anula somente se o termo entre colchetes for nulo, ou seja:

# %% [markdown]
# $$
# \left(\frac{x}{a} \right) - \left(\frac{x}{a} \right)^3 = 0 \Rightarrow \frac{x}{a}\left(1 - \left( \frac{x}{a} \right)^2 \right) = 0.
# $$

# %% [markdown]
# Para que essa relação seja válida, teremos dois casos:

# %% [markdown]
# $$
# (\star) \left\{
# \begin{array}{1}
# \frac{x}{a} = 0  \\
# 1 - \left(\frac{x}{a}\right)^2 =0
# \end{array}
# \right.
# $$

# %% [markdown]
# Resolvemos cada um separadamente para então acharmos todas as posições de equilíbrio do sistema:

# %% [markdown]
# $$
# (\star) \left\{
# \begin{array}{1}
# x = 0 \\
# \left(\frac{x}{a}\right)^2 = 1 \Rightarrow x = \pm \ a
# \end{array}
# \right.
# $$

# %% [markdown]
# Note que, se observarmos o gráfico, veremos que nessas posições, o potencial atinge um máximo ou mínimo local, caracterizado como um ponto de equilíbrio.

# %% [markdown]
# #### c)  Qual será a frequência angular $𝜔_0$ das oscilações em torno do ponto de equilíbrio?

# %% [markdown]
# Para acharmos a frequência de oscilação, devemos fazer algumas considerações. Primeiramente, vamos considerar que as oscilações são idênticas a de um oscilador harmônico simples. Para isso, devemos ter uma força restauradora e um ponto de equilíbrio sobre o qual nossa partícula irá oscilar. Pela forma do gráfico, a única posição de equilíbrio possível é aquela para $x = 0$ (onde existe equilíbrio estável). Dessa maneira, vamos considerar também que o nosso oscilador terá oscilações pequenas, ou seja, sua amplitude será pequena e a partícula vai assumir posições próximas de sua posição de equilíbrio. Vamos analisar a expressão obtida para a força:

# %% [markdown]
# $$
# F(x) -\frac{4 U_0}{a}\left(\frac{x}{a} \right)\left[1 -  \left(\frac{x}{a} \right)^2\right].
# $$

# %% [markdown]
# Se as oscilações são pequenas, $x$ assume valores apenas próximos de $0$.  Vamos utilizar uma aproximação (muito utilizada em problemas físicos canônicos) em que os termos com potência em $x$ maior ou igual a 2 serão desprezados (tendem abruptamente para $0$). Assim sendo, a nossa força se torna:

# %% [markdown]
# $$
# F(x) = -\frac{4 U_0}{a} \frac{x}{a} = -\frac{4 U_0}{a^2}x
# \tag{5.4}
# $$

# %% [markdown]
# A equação (5.4) nos dá a força restauradora que precisávamos para terminarmos de definir nosso oscilador harmônico simples. Escrevendo a segunda Lei de Newton, teremos:

# %% [markdown]
# $$
# m \ddot{x} = -\frac{4 U_0}{a^2}x \Rightarrow \ddot{x} + \frac{4 U_0}{ma^2}x = 0.
# \tag{5.5}
# $$

# %% [markdown]
# Podemos definir a quantidade $\omega_0 ^2 = \frac{4 U_0}{m a^2}$, de forma que (5.4) se torna:

# %% [markdown]
# $$
# \ddot{x} + \omega_0 ^2 x = 0.
# $$

# %% [markdown]
# Essa equação diferencial ordinária rege o movimento da partícula em torno do ponto de equilíbrio $x = 0$. Sua solução é conhecida, na forma:

# %% [markdown]
# $$
# x(t) = A \cos(\omega_0 t + \phi),
# $$

# %% [markdown]
# onde $A$ é a amplitude de oscilação, $\omega_0$ é a frequência angular de oscilação e $\phi$ uma fase. Pela definição de $\omega_0 ^2 \ $, obtemos facilmente a frequência procurada:

# %% [markdown]
# $$
# \omega_0 = \frac{2}{a}\sqrt{\frac{U_0}{m}}
# $$

# %% [markdown]
# #### d) Qual será a velocidade mínima que a partícula deverá ter na origem para escapar para o infinito?

# %% [markdown]
# Vamos considerar que essa velocidade é aquela necessária em que a partícula sai da origem, chega no ponto de equilíbrio instável (prestes a escapar para o infinito) e fica estacionária nessa posição. Esse é o cenário de mais fácil resolução para o problema.

# %% [markdown]
# Para resolvermos essa questão, vamos utilizar a conservação da energia mecânica. Vamos analisar duas posições do nosso sistema: $x = 0$ e $x = a$. Escrevendo a energia mecânica para cada ponto escolhido como a soma da energia potencial e energia cinética:

# %% [markdown]
# $$
# T(0) + U(0) = T(a) + U(a).
# \tag{5.6}
# $$

# %% [markdown]
# Entretanto, propomos que no ponto $a$ (ponto de equilíbrio instável) a partícula ficará estacionária, ou seja, $T(a) = 0$. Além disso, usamos a fórmula do potencial para calcularmos $U(0)$:

# %% [markdown]
# $$
# U(0) = U_0 \left[2 \left(\frac{0}{a} \right)^2 - \left(\frac{0}{a} \right)^4 \right] = 0.
# $$

# %% [markdown]
# Com essas informações, a equação (5.6) se torna apenas:

# %% [markdown]
# $$
# T(0) = U(a).
# $$

# %% [markdown]
# Agora, vamos resolver essa expressão, utilizando a fórmula do potencial para achar $U(a)$ e posteriormente vamos isolar a velocidade $v$, que se refere à velocidade da partícula no ponto $x = 0$:

# %% [markdown]
# $$
# T = U_0 \left[2\left(\frac{a}{a} \right)^2 - \left(\frac{a}{a} \right)^4 \right] \Rightarrow T = U_0 (2 - 1) = U_0
# $$

# %% [markdown]
# Substituindo a expressão para a energia cinética:

# %% [markdown]
# $$
# \frac{m v^2}{2} = U_0 \Rightarrow v = \sqrt{\frac{2 U_0}{m}}
# $$

# %% [markdown]
# Essa é a máxima velocidade que a partícula pode ter na origem para que ela não escape para o infinito.

# %% [markdown]
# #### e)  Em $𝑡 = 0$, a partícula encontra-se na origem e sua velocidade é positiva e igual em magnitude à velocidade do item (d). Determine $𝑥(𝑡)$ e faça um gráfico do resultado.

# %% [markdown]
# Considerando que a partícula começa na origem e se desloca até o ponto de equilíbrio instável (ou seja, a velocidade inicial é a limite para que a partícula não escape para o infinito), obtemos a seguinte relação para a energia mecânica:

# %% [markdown]
# $$
# \frac{1}{2}m v^2 + U(x) = U(a),
# $$

# %% [markdown]
# pois $a$ é o ponto de equilíbrio instável. Com essa relação, estamos dizendo que a energia mecânica em qualquer lugar do sistema é igual a energia potencial no ponto $a$. Isolando a velocidade, temos que:

# %% [markdown]
# \begin{equation}
# v^2 = \frac{2}{m}\left[ U(a)-U(x) \right].
# \tag{5.7}
# \end{equation}

# %% [markdown]
# Agora, vamos resolver a expressão entre colchetes. Sabemos que $U(a) = U_0$. Substituindo essa informação e escrevendo o potencial $U(x)$, teremos:

# %% [markdown]
# $$
# U(a)-U(x) = U_0 - U_0\left[ 2\left(\frac{x}{a} \right)^2 - \left(\frac{x}{a} \right)^4 \right] = U_0\left[1 -  2\left(\frac{x}{a} \right)^2 + \left(\frac{x}{a} \right)^4 \right].
# $$

# %% [markdown]
# Podemos notar que a expressão entre colchetes agora se assemelha ao quadrado da diferença de dois termos. Continuando as operações, obteremos:

# %% [markdown]
# $$
# U(a)-U(x) = U_0\left[1 -  \left(\frac{x}{a} \right)^2  \right]^2
# $$

# %% [markdown]
# Substituindo esta expressão na equação (5.7):

# %% [markdown]
# $$
# v^2 = \frac{2}{m}U_0\left[1 -  \left(\frac{x}{a} \right)^2  \right]^2 \Rightarrow v = \sqrt{\frac{2U_0}{m}} \left[1 -  \left(\frac{x}{a} \right)^2  \right].
# $$

# %% [markdown]
# Note que desprezamos o resultado negativo para a velocidade pois o próprio enunciado nos informa que a esta é positiva. Além disso, pela expressão da velocidade, se fizermos $x = 0$, obtemos a velocidade mínima calculada no item d), como solicitado pelo enunciado. Agora que obtemos uma fórmula para a velocidade, podemos encontrar uma equação para a posição $x(t)$ se lembrarmos que $v = \frac{dx}{dt}$. Arranjando os termos, teremos:

# %% [markdown]
# \begin{equation}
# \int_0 ^x \frac{d{x}^{\prime}}{1-\left( \frac{x}{a}\right)^2} = \int _0 ^t \sqrt{\frac{2U_0}{m}} dt^{\prime}  .
# \tag{5.8}
# \end{equation}

# %% [markdown]
# Agora, resta apenas resolvermos a integração. Por sorte, a integral da direita é trivial de ser resolvida e a da esquerda possui solução tabelada. Teremos então:

# %% [markdown]
# $$
# a \cdot \left. \tanh^{-1}\left({\frac{x^{\prime}}{a}}\right) \right|_0 ^x= t \sqrt{\frac{2U_0}{m}}
# $$

# %% [markdown]
# $$
# \Rightarrow a \cdot \tanh^{-1}\left({\frac{x}{a}}\right) =  t \sqrt{\frac{2U_0}{m}} \Rightarrow \frac{x}{a} = \tanh\left({\frac{t}{a} \sqrt{\frac{2U_0}{m}}}\right).
# $$

# %% [markdown]
# Finalmente, isolando $x$, obtemos:

# %% [markdown]
# $$
# x(t) = a \tanh \left(\frac{t}{a} \sqrt{\frac{2 U_0}{m}} \right)
# \tag{5.9}
# $$

# %% [markdown]
# Apesar da integral em (5.8) ter soluções envolvendo logaritmos naturais, utilizaremos a solução que envolve a função trigonométrica hiperbólica, pois ela é mais comportada, com relação à descontinuidades. Agora, nosso objetivo é fazer o gráfico para esse resultado. Essa tarefa é bem mais trivial que obter o resultado analítico e está descrito a seguir.

# %%
#Definimos o valor da massa da partícula, parâmetro agora necessário para a simulação:
m = 1

# %%
#Definimos a função para a posição exatamente como mostra o resultado analítico em (5.9):
def x(t):
    v = np.sqrt(2*U0/m)
    return a*np.tanh(t*v/a)

# %%
#Fazemos um vetor para armazenarmos o intervalo de tempo escolhido:
tempo = np.linspace(0,5,1000)
#E outro vetor para guardar os valores de x obtidos:
Xp = []

# %%
#Preenchemos o vetor dos valores de x a partir da definição da função, para cada valor de t determinado anteriormente
for t in tempo:
    Xp.append(x(t))

# %%
#Utilizamos o comando padrão para gerar o gráfico
plt.plot(tempo,Xp)
plt.xlabel("t (s)")
plt.ylabel("x (m)")
plt.title("Posição - Questão 5")
plt.grid()
plt.show()

# %% [markdown]
# Como esperado, o gráfico mostra que a partícula se desloca até a posição de equilíbrio instável, e lá permanece de maneira estacionária. Se qualquer acréscimo de velocidade fosse dado, nosso objeto seguiria indefinidamente para o infinito.

# %% [markdown]
# Esse problema envolve diversas etapas ao se trabalhar com potenciais mais complicados. Entretanto, com algumas aproximações, conseguimos encontrar alguns resultados importantes, como a frequência de oscilação em torno do ponto de equilíbrio, ao impormos pequenas oscilações. Além disso, conseguimos montrar a trajetória de uma partícula submetida a esse potencial, considerando que a mesma inicie seu movimento na origem e fique estacionária em um de seus pontos de equilíbrio instável. Conseguimos encontrar a resolução por aparecer simplificações no desenvolvimento do cálculo. Se o potencial fosse um pouco diferente, talvez não tivéssemos conseguido encontrar um resultado analítico.

# %% [markdown]
# ## Problema 6

# %% [markdown]
# **Oscilador harmônico amortecido.** Uma partícula está oscilando com uma amplitude $A= 1cm$ e frequência angular $\omega_0 = 1 rad/s$ com diferentes coeficientes de amortecimento e ângulos de fase inicial. Primeiro vamos demonstrar a equação da posição em relação ao tempo desse movimento oscilatório amortecido.

# %% [markdown]
# **Desenvolvimento teórico:**
#
#
# Vamos escrever a equação da força resultante para a partícula no movimento oscilatório:

# %% [markdown]
# $$F = -kx-b\frac{dx}{dt}$$

# %% [markdown]
# Utilizando a segunda lei de newton para quantificarmos a aceleração:

# %% [markdown]
# $$m\frac{d^2x}{dt^2} = -kx-b\frac{dx}{dt} \Rightarrow m\frac{d^2x}{dt^2}+kx+b\frac{dx}{dt}  = 0$$

# %% [markdown]
# Dividindo tudo por m:

# %% [markdown]
# $$\frac{d^2x}{dt^2}+\frac{k}{m}x+\frac{b}{m}\frac{dx}{dt}  = 0$$

# %% [markdown]
# Para parametrização e garantir a simetria durante a resolução da equação ordinária, vamos considerar as seguintes substituições:

# %% [markdown]
# $$\dfrac{b}{m}= 2\beta$$

# %% [markdown]
# Substituindo, teremos a seguinte a expressão:

# %% [markdown]
# $$
# \frac{d^2x}{dt^2}+\frac{k}{m}x+2\beta\frac{dx}{dt}  = 0
# \tag{6.1}
# $$

# %% [markdown]
# Considerando o movimento oscilatório sem amortecimento, podemos definir o parâmetro da frequência natural do movimento como $\omega_0= \sqrt{\dfrac{k}{m}}$
# Dessa forma, podemos escrever a equação (6.1) da seguinte maneira:

# %% [markdown]
# $$
# \frac{d^2x}{dt^2}+\omega_0^2x+2\beta\frac{dx}{dt}  = 0
# \tag{6.2}
# $$

# %% [markdown]
# Agora precisamos resolver essa equação diferencial ordinária. Vamos escrever a equação homogênea:

# %% [markdown]
# $$\lambda^2 + 2\beta\lambda+\omega_0^2= 0$$

# %% [markdown]
# Resolvendo a equação do segundo grau, para encontrarmos a raízes da equação homogênea:

# %% [markdown]
# $$\lambda= \dfrac{-2\beta \pm \sqrt{4\beta^2 -4\omega_0^2}}{2} \Rightarrow \lambda= \dfrac{-\beta \pm \sqrt{\beta^2 -\omega_0^2}}{1}$$

# %% [markdown]
# Vamos definir a quantidade $\sqrt{-(\beta^2-\omega_0^2)} $ como $\omega'$ ou seja $\omega' = \sqrt{\omega_0^2 - \beta^2} $, já que nesse exemplo sempre temos $ \beta < \omega_0 $ dessa maneira, teremos:

# %% [markdown]
# $$\lambda= \dfrac{-\beta \pm i\omega'}{1} $$

# %% [markdown]
# Então a base para a combinação linear da solução das equações homogêneas:

# %% [markdown]
# $${{e^{-\beta t}cos(\omega't), e^{-\beta t}sen(\omega't)}} $$

# %% [markdown]
# Agora, realizando uma combinação linear entre os elementos da base, com constantes arbitrárias K e D quaisquer:

# %% [markdown]
# $$
# \begin{aligned}
# x(t)= {Ke^{-\beta t}cos(\omega't)+ De^{-\beta t}sen(\omega't)} \\ \\
# x(t)= {e^{-\beta t}(Kcos(\omega't)+ Dsen(\omega't))}
# \end{aligned}
# \tag{6.3}
# $$

# %% [markdown]
# Podemos chamar os coeficientes $K$ e $D$ como funções da amplitude original de oscilação do sistema $A$ e do cosseno da diferença de fase $\delta$ da seguinte forma:

# %% [markdown]
# $$\Biggl\{K = Acos(\delta),
# D= Asen(\delta)$$

# %% [markdown]
# Dessa forma, substituindo na equação (6.3):

# %% [markdown]
# $$
# \begin{aligned}
# x(t)= {e^{-\beta t}(Acos(\delta)cos(\omega't)+ Asen(\delta)sen(\omega't))} \\ \\
# x(t)= {Ae^{-\beta t}(cos(\delta)cos(\omega't)+ sen(\delta)sen(\omega't))}
# \end{aligned}
# \tag{6.4}
# $$

# %% [markdown]
# Utilizando as propriedades da soma dos cossenos, como a que será apresentada abaixo:

# %% [markdown]
# $$cos(A-B)= cos(A)cos(B)+sen(A)sen(b) \tag{6.5}$$

# %% [markdown]
# Usando a equação (6.5) na equação (6.4), teremos:

# %% [markdown]
# $$
# x(t)= {Ae^{-\beta t}cos(\omega't - \delta)}
# \tag{6.6}
# $$

# %% [markdown]
# Agora, derivando a equação (6.6) em relação ao tempo, podemos obter a equação da velocidade em função do tempo, derivando:

# %% [markdown]
# $$
# v(t)= -A\beta e^{-\beta t}cos(\omega't - \delta) - A\omega'e^{-\beta t}sen(\omega't - \delta)
# \tag{6.7}
# $$

# %% [markdown]
# Agora, queremos criar um diagrama de fase que possuirá um ponto P da forma: $P(x,\dot{x})$ então, para fazermos isso, iremos relacionar as expressões (6.6) e (6.7). Como queremos um diagrama de fase entre essas duas funções, vamos fazer com que uma dependa da outra, no caso, $\dot{x}$ dependa de $x$ e de um fator de amortecimento com o tempo devido a própria natureza do movimento. Primeiramente vamos olhar para nossa expressão (6.6):
# $$
# x(t)= {Ae^{-\beta t}cos(\omega't - \delta)}
# \tag{6.6}
# $$
# Perceba que podemos isolar o cosseno, que depende do tempo, em função de x da seguinte maneira:
# $$
# cos(\omega't - \delta)= \frac{x}{Ae^{-\beta t}}
# \tag{6.8}
# $$
# A partir disso podemos encontrar outra relação que será bastante importante no momento de analisarmos a velocidade em função do tempo, podemos utilizar as relações trigonométricas fundamentais e dizer que:
# $$
# cos(\omega't - \delta)^2 = 1-(sen(\omega't - \delta)^2
# $$
# Substituindo o valor do cosseno pela equação (6.8), teremos:
# $$
# sen(\omega't - \delta)^2 = 1 - (\frac{x}{Ae^{-\beta t}})^2
# \tag{6.9}
# $$
# Como pode ser visto na equação (6.7) esse termo será bastante importante para realizarmos a análise.

# %% [markdown]
# Agora, vamos analisar a equação (6.7):
# $$
# \dot{x}= -A\beta e^{-\beta t}cos(\omega't - \delta) - A\omega'e^{-\beta t}sen(\omega't - \delta)
# \tag{6.7}
# $$
# Vamos substituir o termo do cosseno na equação (6.7) pelo equivalente encontrado a expressão (6.8) e teremos:
# $$
# \dot{x}= -\beta x - A\omega'e^{-\beta t}sen(\omega't - \delta)
# \tag{6.10}
# $$
# Analogamente, vamos substituir o termo do seno na equação (6.10) pelo termo equivalente encontrado na equação (6.9) e teremos:
# $$
# \dot{x}= -\beta x - A\omega'e^{-\beta t}\sqrt{1-(\frac{x}{Ae^{-\beta t}})^2}
# \tag{6.11}
# $$
# Trabalhando um pouco mais a expressão, obtemos:
# $$
# \dot{x}= -\beta x - A\omega'e^{-\beta t}\sqrt{\frac{A^2e^{-2\beta t}- x^2}{A^2e^{-2\beta t}}}
# \tag{6.11}
# $$
# $$
# \dot {x}= -\beta x - \omega'\sqrt{A^2e^{-2\beta t}- x^2}
# \tag{6.11}
# $$
# $$
# (\dot{x}+ \beta x)^2= (-\omega'\sqrt{A^2e^{-2\beta t}- x^2})^2
# \tag{6.11}
# $$
#
# $$
# (\dot{x} + \beta x)^2 + \omega'^2 x^2 = \omega'^2 A^2 e^{-2\beta t}
# \tag{6.11}
# $$

# %% [markdown]
# $$
# \frac{(\dot{x} + \beta x)^2}{\omega'^2 A^2} + \frac{x^2}{A^2} = e^{-2\beta t}
# \tag{6.11}
# $$
# Dessa forma, conseguimos visualizar, que o diagrama de fase toma a forma de uma elipse que decai com o tempo se aproximando da origem.

# %% [markdown]
# Agora vamos realizar os  processos para visualizarmos o que está acontecendo graficamente. Às células contendo os códigos necessários para essa visualização irão conter os comentários pertinentes.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Funções que foram obtidas através da análise analítica e que serão utilizadas na resolução do problema
#No caso, a função da posição em relação ao tempo e a derivada primeira, em relação ao tempo, da função da posição
def oscilador_amortecido(A, omega0, beta, delta, t):
    omega1 = np.sqrt(omega0**2 - beta**2)
    x = A * np.exp(-beta * t) * np.cos(omega1 * t - delta)
    dx = -A * beta * np.exp(-beta * t) * np.cos(omega1 * t - delta) \
         - A * omega1 * np.exp(-beta * t) * np.sin(omega1 * t - delta)
    return x, dx

# %%
# Parâmetros que estão presentes em todos os casos solicitados do problema
A = 0.01  # metros (1 cm)
omega0 = 1.0  # rad/s
t = np.linspace(0, 30, 2000)

# %%
# Caso 1: beta = 0.2, delta = pi/2
beta1 = 0.2
delta1 = np.pi / 2
x1, dx1 = oscilador_amortecido(A, omega0, beta1, delta1, t)

# %%
# Caso 2: beta = 0.1, delta = pi
beta2 = 0.1
delta2 = np.pi
x2, dx2 = oscilador_amortecido(A, omega0, beta2, delta2, t)
#Queremos plotar os 2 gráficos no mesmo grid para que assim tenhamos uma melhor comparação
#E para isso foi definido, de antemão, os parâmetros solicitados no caso 2

# %%
# Agora, vamos plotar os gráficos das soluções obtidas dados os respectivos parâmetros
fig, axs = plt.subplots(2, 2, figsize=(15, 8))

# Caso 1
axs[0,0].plot(t, x1, label='x(t)')
axs[0,0].plot(t, dx1, label='dx/dt')
axs[0,0].set_title("x(t) e dx/dt - Caso 1")
axs[0,0].legend()
axs[0,0].grid()

axs[0,1].plot(x1, dx1)
axs[0,1].set_title("Diagrama de fase - Caso 1")
axs[0,1].set_xlabel("x")
axs[0,1].set_ylabel("dx/dt")
axs[0,1].grid()

# Caso 2
axs[1,0].plot(t, x2, label='x(t)')
axs[1,0].plot(t, dx2, label='dx/dt')
axs[1,0].set_title("x(t) e dx/dt - Caso 2")
axs[1,0].legend()
axs[1,0].grid()

axs[1,1].plot(x2, dx2)
axs[1,1].set_title("Diagrama de fase - Caso 2")
axs[1,1].set_xlabel("x")
axs[1,1].set_ylabel("dx/dt")
axs[1,1].grid()

plt.tight_layout()
plt.show()

# %%
# Número de cruzamentos de x = 0 no Caso 1
cruzamentos = np.where(np.diff(np.sign(x1)))[0]
ultima_amplitude = np.max(np.abs(x1[cruzamentos[-1]:]))
print(f"Número de cruzamentos x = 0 (Caso 1): {len(cruzamentos)}")
print(f"Última amplitude após cruzamentos: {ultima_amplitude:.5f} m")
# Out:
# Número de cruzamentos x = 0 (Caso 1): 9
# Última amplitude após cruzamentos: 0.00002 m

# %% [markdown]
# Como é possível visualizar, através dos resultados numéricos, o sistema amortecido cruza o 0 do eixo x o total de 9 vezes. E também, é possível notar, que o primeiro gráfico (x(t), v(t)) vs t) é o mais interessante para se observar o número de vezes que o 0 foi cruzado, pois ele evidencia, de maneira explicíta, o valor de ambas as funções, com o decorrer do tempo, separadamente, tornando assim mais fácil a visualização.

# %% [markdown]
# ## Problema 7

# %% [markdown]
# **Movimento oscilatório subamortecido.** Elaborar um gráfico $X(t)$ Do movimento oscilatório, onde a equação da posição em função do tempo é da forma:
# $$X(t) = Ae^{-\beta t}cos(\omega_1 t - \delta), $$

# %% [markdown]
# onde a amplitude $A$ é igual a $A = 1 cm$, em todas as situações que serão analisadas, o coeficiente de amortecimento $\beta$ e a frequência angular, da oscilação sem amortecimento, $\omega_0$ que estarão relacionadas através da razão $\frac{\beta^2}{\omega_0^2}$ e essa razão poderá assumir os seguintes valores: $[0.1, 0.5, 0.9]$ representando assim movimentos subamortecidos, já que em todos os casos $\beta < \omega_0$. Para cada valor da razão citada, teremos 3 possíveis angulos de fase inicial $\delta$ possíveis com os valores que seguem: $[0, \pi/2, \pi]$ totalizando, assim, nove gráficos ao todo a serem expostos na simulação.

# %% [markdown]
# Vamos começar o processo para visualizarmos graficamente o gráfico com os parâmetros de cada caso.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parâmetros presentes em todos os casos do problema
A = 1.0 #amplitude da oscilação
omega0 = 1.0
t = np.linspace(0, 20, 1000)#Espaçamento do tempo para a visualização gráfica

# %%
# Combinações de beta²/omega0² e delta
r_vals = [0.1, 0.5, 0.9] #como W0 é constante temos o beta de cada caso implícito
delta_vals = [0, np.pi/2, np.pi]

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 10))
fig.suptitle("Movimento Subamortecido", fontsize=16)

for i, r in enumerate(r_vals):#selecionando um dos valores de beta
    beta = np.sqrt(r) * omega0 #obtido a partir da razão dada em cada caso da questão
    omega1 = np.sqrt(omega0**2 - beta**2) #ômega através da convenção utilizada
    
    for j, delta in enumerate(delta_vals): #cada gráfico para um certo valor de beta para todos os valores de delta
        x = A * np.exp(-beta * t) * np.cos(omega1 * t - delta) #oscilação com o amortecimento
        env = A * np.exp(-beta * t) #Envelopamento dos limites da oscilação através da amplitude dada com o passar do tempo
        osc = np.cos(omega1 * t - delta) #oscilação sem o amortecimento
        
        ax = axs[i][j]
        ax.plot(t, x, label="x(t)", color='blue')
        ax.plot(t, env, '--', label="Envelope", color='red')
        ax.plot(t, -env, '--', color='red')
        ax.plot(t, osc, ':', label="cos", color='green')
        
        ax.set_title(f"r = {r}, δ = {delta:.2f} rad")
        ax.set_xlabel("Tempo (s)")
        ax.set_ylabel("x(t)")
        ax.grid(True)
        ax.legend(loc='upper right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# Perceba que, conforme o coeficiente de amortecimento r aumenta, temos, obviamente, um amortecimento cada vez maior que consequentemente dissipa a energia total do sistema mais rapidamente. Os ângulos da diferença de fase indicam em qual posição a oscilação irá "começar" perca que, ao comparmos a diferença de fase de 0 rad e 3.14 rad, temos uma situação simétrica, ou seja, oposta uma com relação a outra.

# %% [markdown]
# ## Problema 8

# %% [markdown]
# **Oscilador senoidal impelido e amortecido 1.**

# %% [markdown]
# Elabore gráficos de $x_p(t)$, $x_c(t)$ e a soma $x(t)$ para um oscilador senoidal impelido e amortecido. Considere $\beta = 0.2$ $\text{s}^{-1}$, $k = 1 \, \text{kg/s}^2$ e $m = 1 \, \text{kg}$.

# %% [markdown]
# $\textbf{Objetivo:}$
#
# Analisar graficamente as soluções, como a Solução Complementar (**transiente**)$x_c(t)$, Solução Particular (**estacionária**) **$x_p(t)$** e Solução Geral $x(t)$ de um oscilador forçado amortecido, explorando como a razão $\frac{\omega}{\omega_1}$ afeta as amplitudes e o comportamento do sistema.
#
# $\textbf{Desenvolvimento teórico:} $
#
# Organizaremos nossa análise em etapas distintas, com fundamentação teórica e código específicos para cada item solicitado.

# %% [markdown]
# **Dinâmica do Oscilador Amortecido**
#
# O movimento representado pelo oscilador harmônico
# simples é denominado oscilação livre. Uma vez colocado
# em oscilação, o movimento nunca cessaria.

# %% [markdown]
# Equacionamento do movimento:
# Para uma partícula de massa $m$ sob ação combinada de:
# 1. **Força restauradora linear**: $-kx$
# 2. **Força de resistência viscosa**: $-b\dot{x}$
#
# A equação diferencial do movimento é derivada da 2ª Lei de Newton:
#
# $$
# \sum_i F_x = m\ddot{x}.
# $$
#
# Substituindo as forças atuantes:
#
# $$
# -kx - b\dot{x} = m\ddot{x}.
# $$
#
# Reorganizando os termos:
#
# $$
# m\ddot{x} + b\dot{x} + kx = 0.
# $$
#
# Forma canônica (dividindo por $m$):
#
# $$
# \ddot{x} + \frac{b}{m}\dot{x} + \frac{k}{m}x = 0.
# $$

# %% [markdown]
# Solução da Equação do Oscilador Amortecido:
#
# Proposta de solução. A equação diferencial admite soluções da forma:
# $$ x(t) = e^{rt}. $$
#
# Derivação da solução:
# A partir desta forma proposta, obtemos:
# $$ \dot{x} = re^{rt}, $$
# $$ \ddot{x} = r^2e^{rt}. $$
#
# Substituição na equação de movimento:
# Inserindo essas expressões na equação diferencial:
# $$ r^2e^{rt} + \frac{b}{m}re^{rt} + \frac{k}{m}e^{rt} = 0. $$
# Que pode ser fatorada como:
# $$ \left[r^2 + \frac{b}{m}r + \frac{k}{m}\right]e^{rt} = 0. $$
#
# Equação característica:
# Como $e^{rt} \neq 0$, obtemos a equação auxiliar:
# $$ r^2 + \frac{b}{m}r + \frac{k}{m} = 0.$$

# %% [markdown]
# Raízes da equação quadrática:
# A solução para $r$ é dada por:
#
# $$
# r = \frac{-(b/m) \pm \sqrt{(b/m)^2 - 4(k/m)}}{2},
# $$
#
# que pode ser reescrita como:
#
# $$
# r = -\left(\frac{b}{2m}\right) \pm \sqrt{\left(\frac{b}{2m}\right)^2 - \left(\frac{k}{m}\right)}.
# $$

# %% [markdown]
# ## Parâmetros fundamentais:
# Definimos:
# - $\beta \equiv \frac{b}{2m}$ (parâmetro de amortecimento)
# - $\omega_0^2 \equiv \frac{k}{m}$ (frequência natural ao quadrado)

# %% [markdown]
# ## Forma simplificada das raízes:
# As soluções da equação característica tornam-se:
#
# $$
# \begin{aligned}
# r_1 &= -\beta + \sqrt{\beta^2 - \omega_0^2} \\
# r_2 &= -\beta - \sqrt{\beta^2 - \omega_0^2}
# \end{aligned}
# $$

# %% [markdown]
# A Equação do Movimento e suas formas equivalentes da equação diferencial:
# 1. Forma original:
#    $$\ddot{x} + \frac{b}{m}\dot{x} + \frac{k}{m}x = 0$$
#
# 2. Forma com parâmetros fundamentais:
#    $$\ddot{x} + 2\beta\dot{x} + \omega_0^2 x = 0$$

# %% [markdown]
# A solução completa para a equação de movimento pode ser expressa como:
#
# Versão com raízes explícitas:
# $$x(t) = A_1 e^{r_1 t} + A_2 e^{r_2 t}$$
# $$x(t) = A_1 e^{\left(-\beta + \sqrt{\beta^2 - \omega_0^2}\right)t} + A_2 e^{\left(-\beta - \sqrt{\beta^2 - \omega_0^2}\right)t}$$
#
# Forma fatorada (mais conveniente):
# $$x(t) = e^{-\beta t} \left[A_1 e^{\sqrt{\beta^2 - \omega_0^2}\,t} + A_2 e^{-\sqrt{\beta^2 - \omega_0^2}\,t}\right]$$
#
# **Onde:**
# - $A_1$ e $A_2$ são constantes determinadas pelas condições iniciais.
# - $\beta = \frac{b}{2m}$ é o coeficiente de amortecimento.
# - $\omega_0 = \sqrt{\frac{k}{m}}$ é a frequência natural não-amortecida.

# %% [markdown]
# # Solução Geral e Casos do Movimento Amortecido
# A solução completa para o sistema é dada por:
#
# $$
# x(t) = e^{-\beta t} \left[ A_1 e^{\sqrt{\beta^2 - \omega_0^2}\,t} + A_2 e^{-\sqrt{\beta^2 - \omega_0^2}\,t} \right]
# $$
#
# ## Três regimes dinâmicos importantes:
#
#  - > 1. **Regime Subamortecido** ($\omega_0^2 > \beta^2$):
#    - O sistema oscila com amplitude decrescente;
#    - Solução contém termos oscilatórios.
#
# - > 2. **Amortecimento Crítico** ($\omega_0^2 = \beta^2$):
#    - Transição entre comportamento oscilatório e não-oscilatório;
#    - Retorno mais rápido ao equilíbrio.
#
# - > 3. **Superamortecimento** ($\omega_0^2 < \beta^2$):
#    - O sistema retorna ao equilíbrio sem oscilar;
#    - Decaimento mais lento que o caso crítico.

# %% [markdown]
# Na nossa questão é facil ver que se trata de um Subamortecimento.
# O $(\omega_0)^2 $ > $ \beta^2 $.

# %% [markdown]
# Para esse caso Subamortecido (ω₀² > β²)
#
# Definimos da frequência amortecida:
#
# - > Introduzimos a frequência angular do oscilador amortecido:
# $$ \omega_1 \equiv \sqrt{\omega_0^2 - \beta^2} $$
# onde $\omega_1^2 > 0$ representa a frequência efetiva do sistema amortecido.
#
# Transformação da solução geral:
# Substituindo $\omega_1$, a solução assume forma complexa:
#
# $$ x(t) = e^{-\beta t} \left[ A_1 e^{i\omega_1 t} + A_2 e^{-i\omega_1 t} \right]. $$
#
# Conversão para forma real:
# Aplicando a identidade de Euler $e^{\pm i\theta} = \cos\theta \pm i\sin\theta$, obtemos:
#
# $$
# \begin{aligned}
# x(t) &= e^{-\beta t} \left[ A_1 (\cos\omega_1 t + i\sin\omega_1 t) + A_2 (\cos\omega_1 t - i\sin\omega_1 t) \right], \\
# &= e^{-\beta t} \left[ (A_1+A_2)\cos\omega_1 t + i(A_1-A_2)\sin\omega_1 t \right],
# \end{aligned}
# $$

# %% [markdown]
# ## Solução em termos de constantes reais:
# Partindo da expressão:
#
# $$ x(t) = e^{-\beta t} \left[ (A_1+A_2)\cos\omega_1 t + i(A_1-A_2)\sin\omega_1 t \right]. $$
#
# Definimos novas constantes reais:
# $$ B_1 = A_1 + A_2, $$
# $$ B_2 = i(A_1 - A_2). $$
#
# Obtendo a forma simplificada:
# $$ x(t) = e^{-\beta t} \left[ B_1 \cos\omega_1 t + B_2 \sin\omega_1 t \right]. $$
#
# ## Representação em forma de amplitude-fase:
# A solução pode ser reescrita como:
# $$ x(t) = A e^{-\beta t} \cos(\omega_1 t - \delta). $$

# %% [markdown]
# Observações: Uma análise teorica, sobre $x_p(t) = D \cos(\omega t - \delta)$ e $\delta = \arctan\left( \frac{2\beta\omega}{\omega_0^2 - \omega^2} \right)$.
# - Pela 2ª lei de Newton $\sum_i F_x = m\ddot{x}$, a equação de movimento torna-se
#
#   $$
#   -kx - b\dot{x} + F_0 \cos \omega t = m\ddot{x}
#   $$
#   $$
#   m\ddot{x} + b\dot{x} + kx = F_0 \cos \omega t
#   $$
#   $$
#   \ddot{x} + \left(\frac{b}{m}\right)\dot{x} + \left(\frac{k}{m}\right)x = \left(\frac{F_0}{m}\right)\cos \omega t
#   $$
#   $$
#   \ddot{x} + 2\beta\dot{x} + \omega_0^2 x = A \cos \omega t. \quad (I)
#   $$
#
#   Onde $A = \frac{F_0}{m}$, $\beta = \frac{b}{2m}$, $\omega_0^2 = \frac{k}{m}$ e $\omega$ é a frequência angular da força de impulsão.
#
# - A solução geral $x(t)$ é a soma de duas partes:
#
#   $$
#   x(t) = x_c(t) + x_p(t). \quad (II)
#   $$
#
# - > **Solução complementar (transiente)** $x_c(t)$: resolve a equação homogênea $\ddot{x} + 2\beta\dot{x} + \omega_0^2 x = 0$,
#
#   $$
#   x_c(t) = e^{-\beta t} \left[ A_1 \exp\left( \sqrt{\beta^2 - \omega_0^2} \, t \right) + A_2 \exp\left( -\sqrt{\beta^2 - \omega_0^2} \, t \right) \right]. \quad (III)
#   $$
#
#   ➤ Decai exponencialmente com o tempo (é dominada pelo termo $e^{-\beta t}$).
#
# - > **Solução particular (estacionária)** $x_p(t)$: que reproduz o lado direito da equação de movimento,
#
#   $$
#   x_p(t) = D \cos(\omega t - \delta). \quad (IV)
#   $$

# %% [markdown]
# Forma geral da solução particular:
# A resposta estacionária do sistema é dada por:
#
# $$
# x_p(t) = D \cos(\omega t - \delta)
# $$
#
# Amplitude da resposta:
# A amplitude $D$ da oscilação forçada é determinada por:
#
# $$
# D = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}}
# $$
#
# Defasagem da resposta:
# O ângulo de fase $\delta$, que representa o atraso da resposta em relação à força externa, é calculado por:
#
# $$
# \delta = \arctan\left( \frac{2\beta\omega}{\omega_0^2 - \omega^2} \right)
# $$
#
# **Onde:**
# - $A$: Amplitude da força externa aplicada
# - $\omega$: Frequência angular da força externa
# - $\omega_0 = \sqrt{k/m}$: Frequência natural do oscilador
# - $\beta = b/2m$: Coeficiente de amortecimento

# %% [markdown]
# Por fim, vamos realizar os processos para visualizarmos graficamentr o que está acontecendo. Às células contendo os códigos necessários para essa visualização irão conter os comentários. Podemos fazer os graficos separadamente com os as condições dada da questão.

# %% [markdown]
# Começaremos com a Letra (b):

# %% [markdown]
# (b) Para a solução $x_c(t)$, $x_c(t) = Ae^{-\beta t} \cos(\omega_1 t - \delta)$, considere o ângulo de fase $\delta = 0$ e a amplitude $A = 1$ $\text{m/s}^2$.

# %% [markdown]
# A solução da letra (b) com o código e comentários.

# %%
# --------------------- Letra (b) ---------------------
# Loop para gerar os gráficos para cada valor de ω/ω1
plt.figure(figsize=(10, 8))

for i, R in enumerate(R_v):
    W = W_1 * R  # Calcula a frequência de impulsão W para o valor da razão
    
    # Expressão de x(t) - Solução
    x_t = np.exp(-beta * t) * np.cos(W_1 * t)
    
    # Plotando o gráfico
    plt.subplot(3, 2, i + 1)  # 3 linhas e 2 colunas para os gráficos
    plt.plot(t, x_t, label=f'ω/ω₁ = {R}')
    plt.title(f'Gráfico de x(t) para ω/ω₁ = {R}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Deslocamento x(t) (m)')
    plt.legend()
    plt.grid(True)

# Ajustar layout para não sobrepor os gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# Todos os gráficos são idênticos porque a solução transiente $x_c(t) = A e^{-\beta t} \cos(\omega_1 t - \delta)$ não depende da frequência da força externa. Como $\beta$ e $\omega_1$ são fixos, a forma do movimento amortecido é sempre a mesma, independentemente da razão $\omega/\omega_1$.

# %% [markdown]
# (c) Para a solução $x_p(t)$, $x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2 \beta^2}} \cos(\omega t - \delta)$, considere $A = 1 \, \text{m/s}^2$, mas calcule $\delta$.

# %% [markdown]
# A solução da letra (c) com o código e comentários.

# %%
# --------------------- Letra c) ---------------------
# Letra c) - Solução estacionária (x_p(t)) com cálculo de δ
plt.figure(figsize=(12, 8))

for i, R in enumerate(R_v):
    W = W_1 * R  # Calcula a frequência de impulsão W para o valor da razão
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))  # Cálculo de δ
    
    # Expressão de x_p(t) - Solução estacionária
    x_p = (1 / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)
    
    # Plotando o gráfico de x_p(t)
    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p, label=f'ω/ω₁ = {R}')
    plt.title(f'Gráfico de x_p(t) para ω/ω₁ = {R}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Deslocamento x(t) (m)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Nesta etapa, são analisadas apenas as soluções estacionárias $x_p(t)$ do sistema, ou seja, aquelas que permanecem após o desaparecimento do termo transiente $x_c(t)$. Essas soluções correspondem à resposta permanente do oscilador à força externa periódica.
#
# A expressão usada foi:
#
# $$
# x_p(t) = \frac{1}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\beta^2 \omega^2}} \cos(\omega t - \delta).
# $$
#
# com
#
# $$
# \delta = \arctan\left( \frac{2\beta \omega}{\omega_0^2 - \omega^2} \right),
# $$
#
# onde $\omega = R \cdot \omega_1$ e $R$ assume diferentes valores.
#
# Os gráficos mostram como a frequência da força externa afeta a amplitude e a defasagem da resposta. Quando $\omega$ se aproxima da frequência natural, ocorre ressonância e a amplitude aumenta. Já em baixas ou altas frequências, a amplitude da resposta tende a ser pequena.
#
# Observa-se também a variação da fase $\delta$, indicando o atraso da resposta em relação à força aplicada.

# %% [markdown]
# (d) O que se observa em relação às amplitudes relativas das duas soluções à medida que $\omega$ aumenta? Por que isto ocorre?

# %% [markdown]
# # Análise das amplitudes com o aumento da frequência ω
#
# À medida que a frequência ω aumenta, observa-se um comportamento distinto nas duas componentes da solução do sistema:
#
# - A **solução transiente** $x_c(t) = Ae^{-\beta t} \cos(\omega_1 t - \delta)$ apresenta uma amplitude que decai exponencialmente com o tempo, independentemente de ω. Esse termo descreve a resposta natural do sistema e tende rapidamente a zero conforme o tempo avança, especialmente para valores maiores de β.

# %% [markdown]
# - A **solução estacionária** $x_p(t) = \dfrac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\beta^2 \omega^2}} \cos(\omega t - \delta)$ tem sua amplitude diretamente influenciada por ω. À medida que ω aumenta, a amplitude de $x_p(t)$ inicialmente cresce, atinge um pico próximo à ressonância (ω ≈ ω₀) e depois tende a diminuir, mas permanece dominante no comportamento do sistema após o desaparecimento do transiente.

# %% [markdown]
# Em regimes de alta frequência (ω ≫ ω₀), a solução estacionária domina completamente a resposta do sistema, uma vez que a componente transiente já terá desaparecido devido ao amortecimento. Portanto, a oscilação observada no longo prazo corresponde essencialmente à solução forçada.

# %% [markdown]
# (e) Para **$\frac{\omega}{\omega_1}$**, considere $A = 20$ $\text{m/s}^2$ para $x_p(t)$ e produza o gráfico novamente.

# %%
# --------------------- Letra e) --------------------- 
# Letra e) - Solução estacionária (x_p(t)) com A = 20 m/s²
A_new = 20  # Nova amplitude

plt.figure(figsize=(12, 8))

for i, R in enumerate(R_v):
    W = W_1 * R  # Calcula a frequência de impulsão W para o valor da razão
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))  # Cálculo de δ
    
    # Expressão de x_p(t) - Solução estacionária com A = 20 m/s²
    x_p = (A_new / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)
    
    # Plotando o gráfico de x_p(t) com A = 20 m/s²
    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p, label=f'ω/ω₁ = {R}')
    plt.title(f'x_p(t) para ω/ω₁ = {R} com A = 20 m/s²')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Deslocamento x(t) (m)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Solução Estacionária $x_p(t)$ com $A = 20 \, \text{m/s}^2$.
#
# Nesta parte, estudamos a solução estacionária $x_p(t)$ para os mesmos valores de $\omega/\omega_1$, mas agora com uma força externa mais intensa, ou seja, com $A = 20 \, \text{m/s}^2$.
#
# A equação utilizada é:
#
# $$
# x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\beta^2 \omega^2}} \cos(\omega t - \delta),
# $$
#
# onde a nova amplitude $A = 20$ torna os efeitos da força mais evidentes.

# %% [markdown]
# Como esperado, todos os gráficos apresentam o mesmo comportamento de oscilação da Letra (c), mas com **amplitudes proporcionalmente maiores**, mantendo a mesma dependência em frequência e fase. O objetivo é visualizar como a resposta do sistema se intensifica com uma força mais forte, sem alterar sua natureza qualitativa.

# %%
# -------------------- Diferença de C e D -------------------- 
plt.figure(figsize=(14, 12))

for i, R in enumerate(R_v):
    W = W_1 * R
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))

    # Letra C: A = 1
    x_p_c = (A / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    # Letra E: A = 20
    x_p_e = (A_new / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    # Subplot lado a lado
    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p_c, label='Letra (c) - A = 1', color='blue')
    plt.plot(t, x_p_e, label='Letra (e) - A = 20', color='red', linestyle='--')
    plt.title(f'Comparação para ω/ω₁ = {R}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('x_p(t) (m)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparação entre as Letras (c) e (e).
#
# Nesta etapa, comparamos graficamente as soluções estacionárias $x_p(t)$ obtidas nas letras (c) e (e) para diferentes razões $\omega/\omega_1$.
#
# A única diferença entre os dois casos é a amplitude $A$ da força externa aplicada:
#
# - **Letra (c):** $A = 1 \, \text{m/s}^2$
# - **Letra (e):** $A = 20 \, \text{m/s}^2$

# %% [markdown]
# A expressão usada foi:
#
# $$
# x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4 \beta^2 \omega^2}} \cos(\omega t - \delta)
# $$
#
# Como podemos observar nos gráficos, **a forma das oscilações é idêntica** entre os dois casos, já que frequência e fase são determinadas pelos parâmetros do sistema e da força. A **única mudança significativa é a escala vertical (amplitude)**: na Letra (e), a força maior gera deslocamentos muito mais amplos, mantendo o mesmo padrão oscilatório.

# %% [markdown]
# Isso evidencia que a amplitude $A$ atua como um **fator de escala** na resposta estacionária, sem alterar a frequência ou o comportamento qualitativo do movimento.

# %% [markdown]
# (a) Produza esses gráficos para valores de $\frac{\omega}{\omega_1}$, iguais a $\frac{1}{9}$, $\frac{1}{3}$, $1.1$, $3$ e $6$.

# %% [markdown]
# $\textbf{Tarefa principal:}$
# Plotar os gráficos para diferentes valores de $\omega/\omega_1$ ($\frac{1}{9}$, $\frac{1}{3}$, $1.1$, $3$ e $6$), comparar as amplitudes das soluções e discutir os efeitos do amortecimento e ressonância.

# %%
# --------------------- Letra a) --------------------- 
# Valores de ω/ω1
R_v = [1/9, 1/3, 1.1, 3, 6]

# Loop para gerar os gráficos para cada valor de ω/ω1
plt.figure(figsize=(10, 8))

for i, ratio in enumerate(R_v):
    W = W_1 * ratio  # Calcula a frequência de impulsão W para o valor da razão
    
    # Expressão de x_c(t) - Função Complementar (Transiente)
    x_c = A*np.exp(-beta*t) * np.cos(W_1 * t - delta)
    
    # Expressão de x_p(t) - Solução Particular (Estacionária)
    x_p = (A / np.sqrt((W_zero**2 - W**2)**2 + 4*W**2*beta**2)) * np.cos(W * t)
    
    # Solução Geral
    x_t = x_c + x_p
    
    # Plotando o gráfico
    plt.subplot(3, 2, i + 1)  # 3 linhas e 2 colunas para os gráficos
    plt.plot(t, x_t, label=f'ω/ω₁ = {ratio}')
    plt.title(f'Gráfico de x(t) para ω/ω₁ = {ratio}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Deslocamento x(t) (m)')
    plt.legend()
    plt.grid(True)

# Ajustar layout para não sobrepor os gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# Neste experimento computacional, analisamos o comportamento da solução geral $x(t)$ de um **oscilador harmônico amortecido sujeito a uma força externa senoidal**, com diferentes valores da razão $\omega / \omega_1$, onde:
#
# - $\omega$ é a **frequência da força externa** (impulsão),
# - $\omega_1 = \sqrt{\omega_0^2 - \beta^2}$ é a **frequência natural do sistema amortecido**, e
# - $\omega_0 = \sqrt{k/m}$ é a frequência natural do sistema sem amortecimento.
#
# Os valores utilizados para a razão $\omega / \omega_1$ foram:
#
# $$
# \frac{\omega}{\omega_1} = \left\{ \frac{1}{9}, \frac{1}{3}, 1.1, 3, 6 \right\}.
# $$
#
# A solução total $x(t)$ é composta de duas partes:
#
# - **Solução complementar (transiente)**:
#   $$
#   x_c(t) = Ae^{-\beta t} \cos(\omega_1 t - \delta),
#   $$
#   que representa o comportamento transitório, desaparecendo ao longo do tempo devido ao amortecimento.
#
# - **Solução particular (estacionária)**:
#   $$
#   x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\beta^2\omega^2}} \cos(\omega t),
#   $$
#   que representa a resposta permanente do sistema à força externa.
#
# ---
#
# ### Interpretação dos Gráficos
#
# Cada gráfico mostra como o deslocamento $x(t)$ evolui no tempo para um valor específico de $\omega / \omega_1$. As principais observações são:
#
# - Para **valores baixos de $\omega / \omega_1$** (como $1/9$ e $1/3$), a resposta do sistema é dominada pela frequência da força externa. A amplitude da oscilação é relativamente pequena, e a oscilação é lenta.
#
# - Em **$\omega / \omega_1 \approx 1$**, ocorre o **fenômeno da ressonância**: a frequência da força se aproxima da frequência natural amortecida do sistema. Isso faz com que a amplitude da oscilação aumente significativamente, mesmo com amortecimento leve. O sistema entra em ressonância, absorvendo mais energia da força externa.
#
# - Para **valores altos de $\omega / \omega_1$** (como $3$ e $6$), a resposta diminui novamente. A força externa oscila muito rápido para transferir eficientemente energia ao sistema, e a amplitude da resposta estacionária diminui.
#
# - Em todos os casos, o termo transiente $x_c(t)$ desaparece com o tempo, deixando apenas a solução estacionária $x_p(t)$ predominando a longo prazo.

# %% [markdown]
# Portanto, um gráfico detalhado da solução Geral $x(t)$:

# %%
# Importa as bibliotecas NumPy e PyLab (matplotlib) para cálculos numéricos e plotagem de gráficos.
from numpy import *  
from pylab import *

# %%
# Configurações base do sistema oscilante (compartilhadas por todos os cenários).(constantes).
beta = 0.2  # s^-1
k = 1.0     # kg/s^2
m = 1.0     # kg

W_zero = np.sqrt(k / m)  # Frequência natural.  => raiz de k/m. 
A = 1.0 # m/s^2 - Amplitude arbitrária da força. A = (F_zero/m) 
W = 1.0 # Frequência de impulsão W
W_1 = np.sqrt(W_zero*2 - beta*2) # Frequência Angular do oscilador Amortecimento.

delta = 0.0  # fase
t = np.linspace(0,20,1000)

# %%
# Expressão de x_c(t) - (Função Complementar(Transiente))
# x(t)_c = np.exp(-beta*t)*(A_1*np.exp(sqrt(beta**2 - W_zero**2)*t)*((A_2*np.exp(-sqrt(beta**2 - W_zero**2)*t))))
x_c = np.exp(-beta*t)* np.cos(W_1*t - delta)

# Expressão de x_p(t) - (Solução Particular (Estacionária))
x_p = (A / np.sqrt((W_zero**2 - W**2)**2 + 4*W**2*beta**2)) * np.cos(W * t)

#print(x_p)
#print(x_c)

#Solução Geral

x_t = x_c + x_p

# %%
# Geração dos Gráficos (x_c(t), x_p(t) e x_t(t)).

# --- Gráfico 1: x_c(t) ---

plt.figure(figsize=(15, 20), dpi=100)

plt.figure(figsize=(6, 2))
plt.plot(t, x_c, color='orange')
plt.title('Solução Complementar x_c(t) (Transiente)')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Gráfico 2: x_p(t) ---
plt.figure(figsize=(6, 2))
plt.plot(t, x_p, color='green')
plt.title('Solução Particular x_p(t) (Estacionária)')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Gráfico 3: x(t) = x_c + x_p ---
plt.figure(figsize=(6, 2))
plt.plot(t, x_t, color='blue')
plt.title('Solução Geral x(t) = x_c(t) + x_p(t)')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Gráfico 4: Todos juntos ---

plt.figure(figsize=(8, 4), dpi=100)
plt.plot(t, x_t, label='x(t) = x_c + x_p', color='blue', linewidth=2)
plt.plot(t, x_p, '--', label='x_p(t)', color='green', alpha=0.8)
plt.plot(t, x_c, ':', label='x_c(t)', color='orange', alpha=0.8)
plt.title('Comparação: Soluções do Oscilador Amortecido Forçado')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.legend()
plt.grid(True)
plt.savefig("grafico_4k.png", dpi=100)
plt.show()

# %% [markdown]
# ## Problema 9

# %% [markdown]
# **Oscilador senoidal impelido e amortecido 2.**

# %% [markdown]
# Elabore gráficos de $x_p(t)$, $x_c(t)$ e a soma $x(t)$ para um oscilador senoidal impelido e amortecido. Considere os valores $\beta = 1 \, \text{s}^{-1}$, $k = 1 \, \text{kg/s}^2$ e $m = 1 \, \text{kg}$.

# %% [markdown]
# $\textbf{Objetivo:}$
# Nesse Problema, o sistema ao ser deslocado e libertado, retorna para sua posição de equilíbrio sem oscilar.
# Seu movimento é Criticamente Amortecido. Vamos analisar o sistema:
# - > **Amortecimento Crítico** ($\omega_0^2 = \beta^2$):
#    - Transição entre comportamento oscilatório e não-oscilatório;
#    - Retorno mais rápido ao equilíbrio.
#
# $\textbf{Desenvolvimento teórico:} $
#
# Vamos organiza as nossas análises em etapas distintas, com fundamentação teórica e código específicos para cada item solicitado na questão.

# %% [markdown]
# ## Solução Geral Inicial:
# Para o oscilador amortecido:
# $$
# x(t) = e^{-\beta t} \left[ A_1 e^{\sqrt{\beta^2 - \omega_0^2}\,t} + A_2 e^{-\sqrt{\beta^2 - \omega_0^2}\,t} \right].
# $$

# %% [markdown]
# ## Caso Crítico:
# Quando $\beta^2 = \omega_0^2$, as raízes da equação característica se degeneram:
#
# $$
# \begin{aligned}
# r_1 &= -\beta + \sqrt{\beta^2 - \omega_0^2}, \\
# r_2 &= -\beta - \sqrt{\beta^2 - \omega_0^2}.
# \end{aligned}
# $$
#
# ## Caso de amortecimento crítico:
# Quando $\beta^2 = \omega_0^2$, as raízes se degeneram para:
#
# $$
# r_1 = r_2 = -\beta,
# $$

# %% [markdown]
# ### Solução (Incompleta):
# $$
# x(t) = e^{-\beta t} [A_1 + A_2] = Be^{-\beta t}
# $$
# - Esta  solução não é uma solução geral porque contém apenas uma constante.

# %% [markdown]
# ## Solução Geral Correta:
# Para raízes duplas, a solução geral é:
# $$
# x_c(t) = (A_1 + B_2 t)e^{-\beta t}
# $$
#
# **Onde:**
# - $A_1$ e $B_2$ são constantes determinadas pelas condições iniciais;
# - O termo $te^{-\beta t}$ surge da degenerescência das raízes;
# - Representa o retorno mais rápido ao equilíbrio sem oscilações.

# %% [markdown]
# **Interpretação Física:**
# - Sistema retorna ao equilíbrio no menor tempo possível;
# - Caso limite entre oscilatório e não-oscilatório;
# - Importante em sistemas de controle e amortecimento.

# %% [markdown]
# Como no Problema 8, podemos usar as mesmas Equações:

# %% [markdown]
# Forma geral da solução particular:
# A resposta estacionária do sistema é dada por:
#
# $$
# x_p(t) = D \cos(\omega t - \delta)
# $$
#
# Amplitude da resposta:
# A amplitude $D$ da oscilação forçada é determinada por:
#
# $$
# D = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}}
# $$
#
# Defasagem da resposta:
# O ângulo de fase $\delta$, que representa o atraso da resposta em relação à força externa, é calculado por:
#
# $$
# \delta = \arctan\left( \frac{2\beta\omega}{\omega_0^2 - \omega^2} \right)
# $$
#
# **Onde:**
# - $A$: Amplitude da força externa aplicada
# - $\omega$: Frequência angular da força externa
# - $\omega_0 = \sqrt{k/m}$: Frequência natural do oscilador
# - $\beta = b/2m$: Coeficiente de amortecimento

# %% [markdown]
# # Solução Geral
#
# ## Composição da solução:
# A solução completa do sistema é dada pela superposição:
#
# $$
# x(t) = x_c(t) + x_p(t)
# $$
#
#  >**Onde:**
# -  $x_c(t)$: Solução complementar (transiente) → Descreve o comportamento livre do sistema;
# - $x_p(t)$: Solução particular (estacionária) → Resposta à força externa.
#
# > **Características:**
# 1. $x_c(t)$ domina no curto prazo (decai exponencialmente);
# 2. $x_p(t)$ domina no longo prazo (regime estacionário);
# 3. A combinação descreve a transição entre os regimes transitório e permanente.

# %% [markdown]
# Vamos resolver a questão fazendo priemira Solução Homegenea, a solução particular e a Solução Geral.
#
# Começaremos com a letra (b):

# %% [markdown]
# (b) Para a solução criticamente amortecida, $x(t) = (A + Bt)e^{-\beta t}$, considere $\delta = 0$, $A = -1 \, \text{m}$ e $B = 1 \, \text{m/s}$.

# %%
# --------------------- Letra (b) ---------------------

beta = 1.0
k = 1.0
m = 1.0
W_0 = np.sqrt(k / m)
t = np.linspace(0, 20, 1000)
A = -1.0
B = 1.0
R_n = [1/9, 1/3, 1.1, 3, 6]

plt.figure(figsize=(15, 10))

for i, R in enumerate(R_n):
    # Para cada razão R = ω / ω₁, calcula-se ω₁
    omega_1 = np.sqrt(W_0**2 - beta**2)
    W = R * omega_1  # frequência externa (não usada diretamente aqui)

    # Solução transiente subamortecida com δ = 0, A = 1 (constantes arbitrárias)
    x_c = (A + B * t) * np.exp(-beta * t)

    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_c, label=f'ω/ω₁ = {R:.2f}')
    plt.title(f'Transiente x_c(t) para ω/ω₁ = {R:.2f}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('x_c(t) (m)')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.suptitle('Transientes x_c(t) para diferentes razões ω/ω₁', y=1.02)
plt.show()

# %% [markdown]
# Neste item - como na questão 8, estão representadas as soluções **transientes** $x_c(t) = (A + Bt)e^{-\beta t}$ para diferentes razões $\omega / \omega_1$. Apesar de variarmos essa razão, **os gráficos resultam idênticos**. Isso ocorre porque:
#
# - A expressão de $x_c(t)$ **não depende de $\omega$**, ou seja, da frequência externa.
# - A solução transiente representa apenas a resposta natural do sistema ao ser perturbado, e **é determinada unicamente pelos parâmetros internos** do sistema (massa, constante elástica, coeficiente de amortecimento e condições iniciais).
# - Como usamos os **mesmos valores de $A$, $B$ e $\beta$ para todas as simulações**, a curva $x_c(t)$ é exatamente a mesma em todos os casos.
#
# Portanto, a variação de $\omega / \omega_1$ não afeta o comportamento de $x_c(t)$, justificando a repetição gráfica entre os diferentes subplots.

# %% [markdown]
# c) Para a solução $x_p(t)$, $x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}} \cos(\omega t - \delta)$, considere $A = 1 \, \text{m/s}^2$ e calcule $\delta$.

# %%
# --------------------- Letra (c) ---------------------


plt.figure(figsize=(12, 10))

for i, R in enumerate(R_n):
    W = W_zero * R  # Corrigido! Frequência externa

    delta = np.arctan((2 * beta * W)/(W_zero**2 - W**2))
    x_p = (A / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p, label=f'ω/ω₀ = {R}')
    plt.title(f'Estacionária x_p(t) para ω/ω₀ = {R:.2f}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('x_p(t) (m)')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Análise Gráfica:
#
# Nesta etapa, são mostradas as soluções **estacionárias** $x_p(t)$ para diferentes razões $\omega / \omega_0$. A partir da análise gráfica, observamos:
#
# - Quando $\omega / \omega_0$ é muito pequeno (por exemplo, $1/9$ ou $1/3$), o sistema oscila com **baixa frequência e pequena amplitude**.
# - Quando a razão se aproxima de $1$, observa-se um **aumento significativo da amplitude**, indicando a proximidade da **ressonância**. Este é o ponto onde o sistema responde mais fortemente à força externa.
# - À medida que $\omega / \omega_0$ cresce além da ressonância (por exemplo, para $3$ ou $6$), a amplitude **diminui** novamente, e a frequência da oscilação **aumenta**, tornando as oscilações mais rápidas e suaves.
# - A fase da oscilação (deslocamento horizontal da curva) também muda com $\omega$, mostrando que o sistema responde com diferentes atrasos conforme a frequência externa varia.
#
# Portanto, graficamente, os efeitos da **ressonância** e do **amortecimento** são claramente visíveis na forma e na amplitude das curvas $x_p(t)$.

# %% [markdown]
# (d) O que se observa em relação às amplitudes relativas das duas soluções à medida que $\omega$ aumenta? Por que isto ocorre?

# %% [markdown]
# **Análise do Comportamento da Amplitude em xₚ(t)**
#
# A solução particular da equação do oscilador forçado e amortecido é dada por:
#
# $$
# x_p(t) = \frac{A}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\beta^2\omega^2}} \cos(\omega t - \delta)
# $$
#
# onde:
# - $A$ é a amplitude da força externa (neste caso, $A = 1 \, \text{m/s}^2$)
# - $\omega$ é a frequência da força externa
# - $\omega_0$ é a frequência natural do sistema não amortecido
# - $\beta$ é o coeficiente de amortecimento
# - $\delta$ é a defasagem (fase), dada por:
#   $$
#   \delta = \arctan\left( \frac{2\beta\omega}{\omega_0^2 - \omega^2} \right)
#   $$
#
# ## Comportamento da Amplitude em Função de ω
#
# À medida que a razão $\omega / \omega_1$ aumenta, observa-se:
#
# - Para **frequências muito baixas** ($\omega \ll \omega_0$):
#   - O denominador é dominado por $(\omega_0^2 - \omega^2)$
#   - Resulta em amplitude pequena
#
# - Quando $\omega \approx \omega_0$ (ressonância):
#   - Amplitude atinge máximo
#   - No amortecimento crítico ($\beta = \omega_0$) a ressonância é suprimida
#
# - Para **frequências altas** ($\omega \gg \omega_0$):
#   - Termo $\omega^4$ domina o denominador
#   - Amplitude cai rapidamente ($x_p(t) \propto 1/\omega^2$ quando $\omega \to \infty$)
#
# ## Conclusão
#
# > *A amplitude da resposta estacionária $x_p(t)$ diminui à medida que a frequência $\omega$ da força externa se afasta da frequência natural $\omega_0$ — tanto para valores menores quanto para valores maiores que $\omega_0$.*
#
# Isso ocorre porque:
# - O sistema responde mais intensamente perto da frequência natural
# - Fora dessa faixa, a inércia (altas frequências) ou rigidez (baixas frequências) limita a resposta

# %% [markdown]
# (e) Para $\frac{\omega}{\omega_1} = 6$, considere $A = 20 \, \text{m/s}^2$ para $x_p(t)$ e produza o gráfico novamente.

# %% [markdown]
# Fiz para  $\frac{\omega}{\omega_1} = 6$ e para todos os outros.

# %%
# --------------------- Letra (e) ---------------------

# Letra e) - Solução estacionária x_p(t) com A = 20 m/s²
A_new = 20  # Nova amplitude

plt.figure(figsize=(12, 10))

for i, R in enumerate(R_n):
    W = W_zero * R  # Frequência da força externa

    # Cálculo do ângulo de fase δ
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))

    # Solução estacionária com nova amplitude A = 20
    x_p = (A_new / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p, label=f'ω/ω₁ = {R}')
    plt.title(f'Solução x_p(t) para ω/ω₁ = {R} com A = 20 m/s²')
    plt.xlabel('Tempo (s)')
    plt.ylabel('x_p(t) (m)')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Análise Gráfica
#
# Na letra (e), observamos a resposta estacionária $x_p(t)$ do sistema para diferentes razões $\omega/\omega_1$, agora com uma amplitude de força externa aumentada para $A = 20 \ \text{m/s}^2$. Comparando com a letra (c), nota-se que a forma geral dos gráficos permanece a mesma, pois ela depende da relação entre $\omega$ e $\omega_0$, além do amortecimento $\beta$. No entanto, a altura dos picos (amplitude da resposta) é significativamente maior, refletindo diretamente o aumento da força aplicada. Esse comportamento é esperado, já que a solução particular é proporcional à amplitude da força externa.

# %%
# --------------------- Comparação Letra (c) vs Letra (e) ---------------------

beta = 0.2  # s^-1
k = 1.0     # kg/s^2
m = 1.0     # kg
A = 1.0     # Amplitude original
A_new = 20  # Nova amplitude para letra e

# Frequências
W_zero = np.sqrt(k / m)
W_1 = np.sqrt(W_zero**2 - beta**2)
t = np.linspace(0, 20, 1000)
R_values = [1/9, 1/3, 1.1, 3, 6]

# Gráficos lado a lado para comparação
plt.figure(figsize=(12, 10))

for i, R in enumerate(R_values):
    W = W_1 * R
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))

    # Letra C: A = 1
    x_p_c = (A / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    # Letra E: A = 20
    x_p_e = (A_new / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    # Subplot lado a lado
    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_p_c, label='Letra (c) - A = 1', color='blue')
    plt.plot(t, x_p_e, label='Letra (e) - A = 20', color='red', linestyle='--')
    plt.title(f'Comparação para ω/ω₁ = {R}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('x_p(t) (m)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparação Gráfica – Letra (c) vs Letra (e)
#
# Nesta comparação, sobrepomos as soluções estacionárias $x_p(t)$ obtidas nas letras (c) e (e), variando a razão $\omega/\omega_1$. A principal diferença entre elas é a amplitude da força externa aplicada: $A = 1 \ \text{m/s}^2$ na letra (c) e $A = 20 \ \text{m/s}^2$ na letra (e). Como a resposta estacionária é diretamente proporcional à amplitude da força, todos os gráficos da letra (e) apresentam a mesma forma dos da letra (c), mas com valores verticais (amplitudes) 20 vezes maiores. Essa comparação evidencia que, enquanto a frequência influencia o padrão de oscilação e a fase do sistema, é a força aplicada que determina o quão intensas serão essas oscilações.

# %% [markdown]
# Respondendo a Letra (a):

# %% [markdown]
# (a) Produza esses gráficos para valores de $\frac{\omega}{\omega_1}$, iguais a $\frac{1}{9}, \frac{1}{3}, 1.1, 3$ e $6$.

# %%
# --------------------- Letra (a) ---------------------

from numpy import *
from pylab import *

# Parâmetros (amortecimento crítico)
beta = 1.0     # s^-1
k = 1.0        # kg/s^2
m = 1.0        # kg
W_zero = np.sqrt(k / m)
A = -1.0       # constante para solução complementar
B = 1.0        # idem
W_1 = np.sqrt(W_zero**2 - beta**2)  # vai dar zero se criticamente amortecido
t = np.linspace(0, 20, 1000)
R_n = [1/9, 1/3, 1.1, 3, 6]  # valores de ω / ω₀

plt.figure(figsize=(15, 10))

for i, R in enumerate(R_n):
    W = W_zero * R  # frequência externa (W = R * ω₀)

    # Solução complementar (crítico): (A + B t) e^(-β t).
    x_c = (A + B * t) * np.exp(-beta * t)

    # Solução particular (forçada).
    delta = np.arctan((2 * beta * W) / (W_zero**2 - W**2))
    x_p = (A / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

    # Solução total
    x_t = x_c + x_p

    # Subgráfico para cada razão ω/ω₀
    plt.subplot(3, 2, i + 1)
    plt.plot(t, x_c, '--', label='x_c(t)')
    plt.plot(t, x_p, ':', label='x_p(t)')
    plt.plot(t, x_t, label='x(t)')
    plt.title(f'ω/ω₀ = {R:.2f}')
    plt.xlabel('Tempo (s)')
    plt.ylabel('Deslocamento x(t)')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.suptitle('Letra (a) - Soluções para diferentes ω/ω₀ (Amortecimento Crítico)', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ### Letra (a) – Soluções para Diferentes Razões $\omega/\omega_0$ (Amortecimento Crítico)
#
# Nesta etapa, analisamos o comportamento do sistema sob **amortecimento crítico** ($\beta = \omega_0$), onde o sistema retorna ao equilíbrio o mais rapidamente possível sem oscilar. Foram plotadas três curvas para cada valor de $\omega/\omega_0$: a **solução complementar** $x_c(t)$ (transiente), a **solução particular** $x_p(t)$ (forçada/estacionária), e a **solução total** $x(t)$.

# %% [markdown]
# A solução complementar segue a forma $(A + B t) e^{-\beta t}$ e decai exponencialmente com o tempo, independentemente da frequência da força externa. Já a solução particular depende de $\omega$ e representa a resposta permanente do sistema à força externa periódica. A solução total combina ambas, mostrando que, no início, o transiente domina, mas com o tempo a resposta estacionária prevalece.

# %% [markdown]
# Com isso, observamos como diferentes razões $\omega/\omega_0$ afetam a amplitude e o padrão de oscilação da parte estacionária, enquanto a parte transiente decai sempre da mesma forma. A superposição das duas formas resulta em padrões iniciais distintos para cada caso, mas com convergência à oscilação forçada a longo prazo.

# %% [markdown]
# Portanto, um gráfico detalhado da solução Geral $x(t)$:

# %%
from numpy import *
from pylab import *

# %%
beta = 1.0  # coeficiente de amortecimento (s^-1)
k = 1.0     # constante da mola (kg/s^2)
m = 1.0     # massa (kg)

W_zero = np.sqrt(k / m)  # frequência natural não amortecid. => raiz de k/m. 
A = 1.0     # m/s^2 - Amplitude arbitrária da força. A = (F_zero/m). amplitude da força externa.
A_1, A_2 = 1.0, 1.0      # constantes arbitrárias da solução complementar
W = 1.0     # Frequência de impulsão W. frequência da força externa.
W_1 = np.sqrt(W_zero**2 - beta**2) # Frequência Angular do oscilador Amortecimento. Frequência do sistema amortecido.
delta = 0.0 # fase 

# Tempo
t = np.linspace(0, 20, 1000)

# %%
# Expressão de x(t)_c - (Função Complementar(Transiente))
# x(t)_c = np.exp(-beta*t)*(A_1*np.exp(sqrt(beta**2 - W_zero**2)*t)*((A_2*np.exp(-sqrt(beta**2 - W_zero**2)*t))))
x_c = np.exp(-beta*t) * (A_1 * np.cos(W_1 * t) + A_2 * np.sin(W_1 * t)) # amortecimento leve (subamortecido).

# Expressão de x_p(t) - (Solução Particular (Estacionária))
x_p = (A / np.sqrt((W_zero**2 - W**2)**2 + 4 * W**2 * beta**2)) * np.cos(W * t - delta)

#print(x_p)
#print(x_c)

# Solução geral

x_t = x_c + x_p

# %%
# --- Gráfico 1: x_c(t) ---

plt.figure(figsize=(15, 20), dpi=100)

plt.figure(figsize=(8, 4))
plt.plot(t, x_c, color='orange')
plt.title('Solução Complementar x_c(t) (Transiente)')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.grid(True)
plt.tight_layout()
plt.show()


# --- Gráfico 2: x_p(t) ---
plt.figure(figsize=(8, 4))
plt.plot(t, x_p, color='green')
plt.title('Solução Particular x_p(t) (Estacionária)')
plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.grid(True)
plt.tight_layout()
plt.show()

# --- Gráfico 3: x(t) = x_c + x_p ---
plt.figure(figsize=(12, 8))

plt.plot(t, x_c, label='Transiente (x_c)', linestyle='--')
plt.plot(t, x_p, label='Estacionário (x_p)', linestyle='-.')
plt.plot(t, x_t, label='Solução Total (x_t)', linewidth=2)

plt.xlabel('Tempo (s)')
plt.ylabel('Deslocamento (m)')
plt.title('Oscilador Senoidal Impelido e Amortecido')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Problema 10

# %% [markdown]
# **Amplitude de ressonância:** Fazer um gráfico da amplitude $A$ versus a razão de frequência $\frac{\omega}{\omega_0}$ para diferentes valores de $\gamma$.
#
# **Objetivos:** Verificar o que acontece com a amplitude de ressonância para diferentes valores de $\gamma$ em relação a $\frac{\omega}{\omega_0}$. Verificar a variação do ângulo de fase $\phi$ com a razão da frequência $\frac{\omega}{\omega_0}$. Verificar os efeitos da variação do valor de $\gamma$ para valores maiores do que 1 no primeiro caso e para valores menores que 1 no segundo caso.

# %% [markdown]
# Vamos utilizar as equações que já foram demonstradas nas questões 8 e 9 e iremos realizar o tratamento computacional. Vamos analisar a solução proposta para uma força de natureza harmônica, que segue acompanha a natureza do movimento oscilatório. No caso, um $ x(t)$ que terá a seguinte forma:

# %% [markdown]
# $$
# x(t)= \frac{A_0 cos(\omega t - \delta)}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}}
# \tag{10.1}
# $$

# %% [markdown]
# Lembrando que se $\gamma$ é nosso coeficiente de armotecimento e beta também é nosso coeficiente de amortecimento, então:

# %% [markdown]
# $$
# \gamma= 2\beta
# \tag{10.2}
# $$

# %% [markdown]
# Vamos analisar a parte da amplitude nessa equação, no caso teríamos um A($\omega$) da seguinte maneira:

# %% [markdown]
# $$
# A(\omega) = \frac{A_0}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}}
# \tag{10.3}
# $$

# %% [markdown]
# Onde na nossa solução proposta, nas questões anteriores, temos que $A_0$ é da forma:

# %% [markdown]
# $$A_0 = F_0/m$$

# %% [markdown]
# Dos mesmos princípios das equações que levaram ao respectivo resultado da oscilação impelida, com a força de forma harmônica, também foi possível obter, nas questões anteriores, a relação entre a diferença de fase $\phi$ com a frequência angular da força atuante na solução proposta e também a frequência angular natural de oscilação, sendo a relação da forma:

# %% [markdown]
# $$
# \phi(\omega)= \tan^{-1}\left(\frac{2\beta\omega}{\omega_0^2 - \omega^2}\right)
# \tag{10.4}
# $$

# %% [markdown]
# Dessa forma, podemos dar início ao tratamento computacional com as respectivas funções que foram obtidas.

# %%
#Importando as bibliotecas necessárias para a criação das funções e visualização gráfica
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parâmetros fixos
m = 1.0      # kg
k = 1.0      # N/m constante da força restauradora 
F0 = 1.0     # Força externa
omega0 = np.sqrt(k/m)  # Frequência natural

# Fatores de amortecimento (gamma = 2*beta), com casos <1, =1, >1
gammas = [0.5, 1.0, 2.0]
# Frequências para simular
omega = np.linspace(0.1, 2*omega0, 1000)

# %%
# Gráfico da amplitude
for gamma in gammas:
    beta = gamma/2
    A = (F0/m) / np.sqrt( (omega0**2 - omega**2)**2 + (2*beta*omega)**2 )
    plt.plot(omega/omega0, A, label=f'gamma = {gamma}')

plt.xlabel(r'$\omega/\omega_0$')
plt.ylabel('Amplitude A($\omega$)')
plt.title('Amplitude de Ressonância')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\o'
# <>:8: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\José Emanuel\AppData\Local\Temp\ipykernel_6348\742494768.py:8: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('Amplitude A($\omega$)')

# %%
# Gráfico do ângulo de fase
for gamma in gammas:
    beta = gamma/2
    phi = np.arctan2(2*beta*omega, omega0**2 - omega**2)
    plt.plot(omega/omega0, phi, label=f'gamma = {gamma}')

plt.xlabel(r'$\omega/\omega_0$')
plt.ylabel('Ângulo de fase $\phi(\omega)$ (rad)')
plt.title('Ângulo de Fase')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\José Emanuel\AppData\Local\Temp\ipykernel_6348\1301500855.py:8: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('Ângulo de fase $\phi(\omega)$ (rad)')

# %% [markdown]
# **Efeitos da utilização de gammas maiores que 1 no item (a):**
# Utilizar valores de gamma maiores do que 1 tem efeitos consideráveis na amplitude. Vamos olhar novamente para a equação (2)

# %% [markdown]
# $$
# A(\omega) = \frac{A_0}{\sqrt{(\omega_0^2 - \omega^2)^2 + 4\omega^2\beta^2}}
# \tag{10.3}
# $$

# %% [markdown]
# E lembrando da nossa equação 2 que estabelece uma relação entre gamma e beta:

# %% [markdown]
# $$
# \gamma= 2\beta
# \tag{10.2}
# $$

# %% [markdown]
# Temos que quanto maior for o gamma maior será o beta e , portanto, o denominador da nossa equação (3) será maior e consequentemente a amplitude será menor. Ou seja, haverá um alargamento no gráfico da nossa amplitude, o que tornará a ressonância praticamente imperceptível, característica de termos uma baixa amplitude já que o aumento do gamma implica na redução da mesma por conta do aumento do denominador, como é evidente pela equação (3).

# %% [markdown]
# **Efeitos da utilização de gammas menores que 1 no item (b):**
# Como é possível visualizar no gráfico da diferença de fase, a transição em torno da frequência angular natural de oscilação é mais brusca para gammas menores em relação a gammas com valores mais altos (maiores que 1), mostrando que o sistema responde rapidamente a força externa que está sendo aplicada não havendo uma grande defasagem.

# %% [markdown]
# ## Problema 11

# %% [markdown]
# ## Problema 12
